# %%
import sys

# %%
sys.executable
# for use with
# /usr/local/opt/python@3.8/bin/python3.8 -m pip install ipython-sql
# Out:
# '/usr/local/opt/python@3.8/bin/python3.8'

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db

# %%
# %%sql
# SELECT *
#   FROM sqlite_master
#  WHERE type='table';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('table', 'album', 'album', 2, 'CREATE TABLE [album]\n(\n    [album_id] INTEGER PRIMARY KEY NOT NULL,\n    [title] NVARCHAR(160)  NOT NULL,\n    [artist_id] INTEGER  NOT NULL,\n    FOREIGN KEY ([artist_id]) REFERENCES [artist] ([artist_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'artist', 'artist', 3, 'CREATE TABLE [artist]\n(\n    [artist_id] INTEGER PRIMARY KEY NOT NULL,\n    [name] NVARCHAR(120)\n)'),
#  ('table', 'customer', 'customer', 4, 'CREATE TABLE [customer]\n(\n    [customer_id] INTEGER PRIMARY KEY NOT NULL,\n    [first_name] NVARCHAR(40)  NOT NULL,\n    [last_name] NVARCHAR(20)   ... (276 characters truncated) ...  [support_rep_id] INTEGER,\n    FOREIGN KEY ([support_rep_id]) REFERENCES [employee] ([employee_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'employee', 'employee', 5, 'CREATE TABLE [employee]\n(\n    [employee_id] INTEGER PRIMARY KEY NOT NULL,\n    [last_name] NVARCHAR(20)  NOT NULL,\n    [first_name] NVARCHAR(20)   ... (310 characters truncated) ... 4),\n    [email] NVARCHAR(60),\n    FOREIGN KEY ([reports_to]) REFERENCES [employee] ([employee_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'genre', 'genre', 6, 'CREATE TABLE [genre]\n(\n    [genre_id] INTEGER PRIMARY KEY NOT NULL,\n    [name] NVARCHAR(120)\n)'),
#  ('table', 'invoice', 'invoice', 7, 'CREATE TABLE [invoice]\n(\n    [invoice_id] INTEGER PRIMARY KEY NOT NULL,\n    [customer_id] INTEGER  NOT NULL,\n    [invoice_date] DATETIME  NOT NUL ... (195 characters truncated) ... tal] NUMERIC(10,2)  NOT NULL,\n    FOREIGN KEY ([customer_id]) REFERENCES [customer] ([customer_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'invoice_line', 'invoice_line', 8, 'CREATE TABLE [invoice_line]\n(\n    [invoice_line_id] INTEGER PRIMARY KEY NOT NULL,\n    [invoice_id] INTEGER  NOT NULL,\n    [track_id] INTEGER  NOT ... (161 characters truncated) ...  DELETE NO ACTION ON UPDATE NO ACTION,\n    FOREIGN KEY ([track_id]) REFERENCES [track] ([track_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'media_type', 'media_type', 9, 'CREATE TABLE [media_type]\n(\n    [media_type_id] INTEGER PRIMARY KEY NOT NULL,\n    [name] NVARCHAR(120)\n)'),
#  ('table', 'playlist', 'playlist', 10, 'CREATE TABLE [playlist]\n(\n    [playlist_id] INTEGER PRIMARY KEY NOT NULL,\n    [name] NVARCHAR(120)\n)'),
#  ('table', 'playlist_track', 'playlist_track', 11, 'CREATE TABLE [playlist_track]\n(\n    [playlist_id] INTEGER  NOT NULL,\n    [track_id] INTEGER  NOT NULL,\n    CONSTRAINT [pk_playlist_track] PRIMARY ... (114 characters truncated) ...  DELETE NO ACTION ON UPDATE NO ACTION,\n    FOREIGN KEY ([track_id]) REFERENCES [track] ([track_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)'),
#  ('table', 'track', 'track', 13, 'CREATE TABLE [track]\n(\n    [track_id] INTEGER PRIMARY KEY NOT NULL,\n    [name] NVARCHAR(200)  NOT NULL,\n    [album_id] INTEGER,\n    [media_type_ ... (377 characters truncated) ... ON ON UPDATE NO ACTION,\n    FOREIGN KEY ([media_type_id]) REFERENCES [media_type] ([media_type_id]) \n\t\tON DELETE NO ACTION ON UPDATE NO ACTION\n)')]

# %%
# Tracks by album name; subquery before the main query using a WITH clause

# %%
# %%sql
# WITH track_info AS
#  (
#      SELECT
#         t.name as track_name,
#         artist.name as artist,
#         album.title album_name,
#         t.milliseconds length_milliseconds,
#         (t.milliseconds / 1000) length_seconds
#
#      FROM track t
#      INNER JOIN album ON album.album_id = t.album_id
#      INNER JOIN artist ON artist.artist_id = album.artist_id
#   )
#
# SELECT * FROM track_info
# WHERE album_name = "Ride The Lightning";
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Fight Fire With Fire', 'Metallica', 'Ride The Lightning', 285753, 285),
#  ('Ride The Lightning', 'Metallica', 'Ride The Lightning', 397740, 397),
#  ('For Whom The Bell Tolls', 'Metallica', 'Ride The Lightning', 311719, 311),
#  ('Fade To Black', 'Metallica', 'Ride The Lightning', 414824, 414),
#  ('Trapped Under Ice', 'Metallica', 'Ride The Lightning', 244532, 244),
#  ('Escape', 'Metallica', 'Ride The Lightning', 264359, 264),
#  ('Creeping Death', 'Metallica', 'Ride The Lightning', 396878, 396),
#  ('The Call Of Ktulu', 'Metallica', 'Ride The Lightning', 534883, 534)]

# %%
# %%sql
#
# WITH playlist_info AS
#   (
#      SELECT
#         playlist.playlist_id,
#         playlist.name playlist_name,
#         track.name track_name,
#         (track.milliseconds / 1000) length_seconds
#      FROM playlist
#      LEFT JOIN playlist_track ON playlist_track.playlist_id = playlist.playlist_id
#      LEFT JOIN track ON track.track_id = playlist_track.track_id
#   )
#
# SELECT
#     playlist_id,
#     playlist_name,
#     COUNT(track_name) number_of_tracks,
#     SUM(length_seconds) length_seconds
# FROM playlist_info
# GROUP BY 1, 2
# ORDER BY 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Music', 3290, 876049),
#  (2, 'Movies', 0, None),
#  (3, 'TV Shows', 213, 500987),
#  (4, 'Audiobooks', 0, None),
#  (5, '90’s Music', 1477, 397970),
#  (6, 'Audiobooks', 0, None),
#  (7, 'Movies', 0, None),
#  (8, 'Music', 3290, 876049),
#  (9, 'Music Videos', 1, 294),
#  (10, 'TV Shows', 213, 500987),
#  (11, 'Brazilian Music', 39, 9464),
#  (12, 'Classical', 75, 21736),
#  (13, 'Classical 101 - Deep Cuts', 25, 6742),
#  (14, 'Classical 101 - Next Steps', 25, 7565),
#  (15, 'Classical 101 - The Basics', 25, 7429),
#  (16, 'Grunge', 15, 4114),
#  (17, 'Heavy Metal Classic', 26, 8189),
#  (18, 'On-The-Go 1', 1, 197)]

# %%
# Creating a custom View first; querying that view right after

# %%
# %%sql
# CREATE VIEW usa_customer_90_dollars AS
#     SELECT
#         customer.*
#     FROM invoice
#     INNER JOIN customer ON invoice.customer_id = customer.customer_id
#     WHERE country = "USA"
#     GROUP BY 1
#     HAVING SUM(invoice.total) > 90;
#
# SELECT * FROM usa_customer_90_dollars;
# Out:
#  * sqlite:///chinook.db
# (sqlite3.OperationalError) table usa_customer_90_dollars already exists
# [SQL: CREATE VIEW usa_customer_90_dollars AS
#     SELECT
#         customer.*
#     FROM invoice
#     INNER JOIN customer ON invoice.customer_id = customer.customer_id
#     WHERE country = "USA"
#     GROUP BY 1
#     HAVING SUM(invoice.total) > 90;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# DROP VIEW usa_customer_90_dollars;
# Out:
#  * sqlite:///chinook.db
# Done.
# []

# %%
# Where regular joins are used to join columns, the union operator is used to join rows from tables and/or views.
# Create two unique views here and make a Union for cheap americans.

# %%
# %%sql
# CREATE VIEW americans AS
#     SELECT * FROM customer
#     WHERE country = "USA";
#
# CREATE VIEW penny_pinchers AS
#     SELECT
#         customer.*
#     FROM invoice
#     INNER JOIN customer ON invoice.customer_id = customer.customer_id
#     GROUP BY 1
#     HAVING SUM(invoice.total) < 20;
#
# SELECT * FROM americans
#
# UNION
#
# SELECT * FROM penny_pinchers;
# Out:
#  * sqlite:///chinook.db
# (sqlite3.OperationalError) table americans already exists
# [SQL: CREATE VIEW americans AS
#     SELECT * FROM customer
#     WHERE country = "USA";]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# DROP VIEW americans;

# %%
# %%sql
#
# WITH cheap_americans AS
#     (
#         SELECT * FROM americans
#
#         INTERSECT
#
#         SELECT * FROM penny_pinchers
#     )
#
#
# SELECT
#     employee.first_name || " " || employee.last_name employee_name,
#     COUNT(cheapo.customer_id) cheap_americans
# FROM employee
#
# LEFT JOIN cheap_americans cheapo ON cheapo.support_rep_id = employee.employee_id
#
# WHERE employee.title = "Sales Support Agent"
# GROUP BY 1 ORDER BY 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Jane Peacock', 0), ('Margaret Park', 0), ('Steve Johnson', 0)]

# %%
# with clauses allow you to define one or more named subqueries. for creating more than one named subquery. 
# To do this, you use a single WITH clause and multiple, comma-separated alias/subquery pairs:

# %%
# BEST CUSTOMER IN EACH COUNTRY

# %%
# %%sql
# WITH
#     customer_country_purchases AS
#         (
#          SELECT
#              i.customer_id,
#              c.country,
#              SUM(i.total) total_purchases
#          FROM invoice i
#          INNER JOIN customer c ON i.customer_id = c.customer_id
#          GROUP BY 1, 2
#         ),
#     country_max_purchase AS
#         (
#          SELECT
#              country,
#              MAX(total_purchases) max_purchase
#          FROM customer_country_purchases
#          GROUP BY 1
#         ),
#     country_best_customer AS
#         (
#          SELECT
#             cmp.country,
#             cmp.max_purchase,
#             (
#              SELECT ccp.customer_id
#              FROM customer_country_purchases ccp
#              WHERE ccp.country = cmp.country AND cmp.max_purchase = ccp.total_purchases
#             ) customer_id
#          FROM country_max_purchase cmp
#         )
# SELECT
#     cbc.country country,
#     c.first_name || " " || c.last_name customer_name,
#     cbc.max_purchase total_purchased
# FROM customer c
# INNER JOIN country_best_customer cbc ON cbc.customer_id
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Argentina', 'Luís Gonçalves', 39.6),
#  ('Argentina', 'Leonie Köhler', 39.6),
#  ('Argentina', 'François Tremblay', 39.6),
#  ('Argentina', 'Bjørn Hansen', 39.6),
#  ('Argentina', 'František Wichterlová', 39.6),
#  ('Argentina', 'Helena Holý', 39.6),
#  ('Argentina', 'Astrid Gruber', 39.6),
#  ('Argentina', 'Daan Peeters', 39.6),
#  ('Argentina', 'Kara Nielsen', 39.6),
#  ('Argentina', 'Eduardo Martins', 39.6),
#  ('Argentina', 'Alexandre Rocha', 39.6),
#  ('Argentina', 'Roberto Almeida', 39.6),
#  ('Argentina', 'Fernanda Ramos', 39.6),
#  ('Argentina', 'Mark Philips', 39.6),
#  ('Argentina', 'Jennifer Peterson', 39.6),
#  ('Argentina', 'Frank Harris', 39.6),
#  ('Argentina', 'Jack Smith', 39.6),
#  ('Argentina', 'Michelle Brooks', 39.6),
#  ('Argentina', 'Tim Goyer', 39.6),
#  ('Argentina', 'Dan Miller', 39.6),
#  ('Argentina', 'Kathy Chase', 39.6),
#  ('Argentina', 'Heather Leacock', 39.6),
#  ('Argentina', 'John Gordon', 39.6),
#  ('Argentina', 'Frank Ralston', 39.6),
#  ('Argentina', 'Victor Stevens', 39.6),
#  ('Argentina', 'Richard Cunningham', 39.6),
#  ('Argentina', 'Patrick Gray', 39.6),
#  ('Argentina', 'Julia Barnett', 39.6),
#  ('Argentina', 'Robert Brown', 39.6),
#  ('Argentina', 'Edward Francis', 39.6),
#  ('Argentina', 'Martha Silk', 39.6),
#  ('Argentina', 'Aaron Mitchell', 39.6),
#  ('Argentina', 'Ellie Sullivan', 39.6),
#  ('Argentina', 'João Fernandes', 39.6),
#  ('Argentina', 'Madalena Sampaio', 39.6),
#  ('Argentina', 'Hannah Schneider', 39.6),
#  ('Argentina', 'Fynn Zimmermann', 39.6),
#  ('Argentina', 'Niklas Schröder', 39.6),
#  ('Argentina', 'Camille Bernard', 39.6),
#  ('Argentina', 'Dominique Lefebvre', 39.6),
#  ('Argentina', 'Marc Dubois', 39.6),
#  ('Argentina', 'Wyatt Girard', 39.6),
#  ('Argentina', 'Isabelle Mercier', 39.6),
#  ('Argentina', 'Terhi Hämäläinen', 39.6),
#  ('Argentina', 'Ladislav Kovács', 39.6),
#  ('Argentina', "Hugh O'Reilly", 39.6),
#  ('Argentina', 'Lucas Mancini', 39.6),
#  ('Argentina', 'Johannes Van der Berg', 39.6),
#  ('Argentina', 'Stanisław Wójcik', 39.6),
#  ('Argentina', 'Enrique Muñoz', 39.6),
#  ('Argentina', 'Joakim Johansson', 39.6),
#  ('Argentina', 'Emma Jones', 39.6),
#  ('Argentina', 'Phil Hughes', 39.6),
#  ('Argentina', 'Steve Murray', 39.6),
#  ('Argentina', 'Mark Taylor', 39.6),
#  ('Argentina', 'Diego Gutiérrez', 39.6),
#  ('Argentina', 'Luis Rojas', 39.6),
#  ('Argentina', 'Manoj Pareek', 39.6),
#  ('Argentina', 'Puja Srivastava', 39.6),
#  ('Australia', 'Luís Gonçalves', 81.18),
#  ('Australia', 'Leonie Köhler', 81.18),
#  ('Australia', 'François Tremblay', 81.18),
#  ('Australia', 'Bjørn Hansen', 81.18),
#  ('Australia', 'František Wichterlová', 81.18),
#  ('Australia', 'Helena Holý', 81.18),
#  ('Australia', 'Astrid Gruber', 81.18),
#  ('Australia', 'Daan Peeters', 81.18),
#  ('Australia', 'Kara Nielsen', 81.18),
#  ('Australia', 'Eduardo Martins', 81.18),
#  ('Australia', 'Alexandre Rocha', 81.18),
#  ('Australia', 'Roberto Almeida', 81.18),
#  ('Australia', 'Fernanda Ramos', 81.18),
#  ('Australia', 'Mark Philips', 81.18),
#  ('Australia', 'Jennifer Peterson', 81.18),
#  ('Australia', 'Frank Harris', 81.18),
#  ('Australia', 'Jack Smith', 81.18),
#  ('Australia', 'Michelle Brooks', 81.18),
#  ('Australia', 'Tim Goyer', 81.18),
#  ('Australia', 'Dan Miller', 81.18),
#  ('Australia', 'Kathy Chase', 81.18),
#  ('Australia', 'Heather Leacock', 81.18),
#  ('Australia', 'John Gordon', 81.18),
#  ('Australia', 'Frank Ralston', 81.18),
#  ('Australia', 'Victor Stevens', 81.18),
#  ('Australia', 'Richard Cunningham', 81.18),
#  ('Australia', 'Patrick Gray', 81.18),
#  ('Australia', 'Julia Barnett', 81.18),
#  ('Australia', 'Robert Brown', 81.18),
#  ('Australia', 'Edward Francis', 81.18),
#  ('Australia', 'Martha Silk', 81.18),
#  ('Australia', 'Aaron Mitchell', 81.18),
#  ('Australia', 'Ellie Sullivan', 81.18),
#  ('Australia', 'João Fernandes', 81.18),
#  ('Australia', 'Madalena Sampaio', 81.18),
#  ('Australia', 'Hannah Schneider', 81.18),
#  ('Australia', 'Fynn Zimmermann', 81.18),
#  ('Australia', 'Niklas Schröder', 81.18),
#  ('Australia', 'Camille Bernard', 81.18),
#  ('Australia', 'Dominique Lefebvre', 81.18),
#  ('Australia', 'Marc Dubois', 81.18),
#  ('Australia', 'Wyatt Girard', 81.18),
#  ('Australia', 'Isabelle Mercier', 81.18),
#  ('Australia', 'Terhi Hämäläinen', 81.18),
#  ('Australia', 'Ladislav Kovács', 81.18),
#  ('Australia', "Hugh O'Reilly", 81.18),
#  ('Australia', 'Lucas Mancini', 81.18),
#  ('Australia', 'Johannes Van der Berg', 81.18),
#  ('Australia', 'Stanisław Wójcik', 81.18),
#  ('Australia', 'Enrique Muñoz', 81.18),
#  ('Australia', 'Joakim Johansson', 81.18),
#  ('Australia', 'Emma Jones', 81.18),
#  ('Australia', 'Phil Hughes', 81.18),
#  ('Australia', 'Steve Murray', 81.18),
#  ('Australia', 'Mark Taylor', 81.18),
#  ('Australia', 'Diego Gutiérrez', 81.18),
#  ('Australia', 'Luis Rojas', 81.18),
#  ('Australia', 'Manoj Pareek', 81.18),
#  ('Australia', 'Puja Srivastava', 81.18),
#  ('Austria', 'Luís Gonçalves', 69.3),
#  ('Austria', 'Leonie Köhler', 69.3),
#  ('Austria', 'François Tremblay', 69.3),
#  ('Austria', 'Bjørn Hansen', 69.3),
#  ('Austria', 'František Wichterlová', 69.3),
#  ('Austria', 'Helena Holý', 69.3),
#  ('Austria', 'Astrid Gruber', 69.3),
#  ('Austria', 'Daan Peeters', 69.3),
#  ('Austria', 'Kara Nielsen', 69.3),
#  ('Austria', 'Eduardo Martins', 69.3),
#  ('Austria', 'Alexandre Rocha', 69.3),
#  ('Austria', 'Roberto Almeida', 69.3),
#  ('Austria', 'Fernanda Ramos', 69.3),
#  ('Austria', 'Mark Philips', 69.3),
#  ('Austria', 'Jennifer Peterson', 69.3),
#  ('Austria', 'Frank Harris', 69.3),
#  ('Austria', 'Jack Smith', 69.3),
#  ('Austria', 'Michelle Brooks', 69.3),
#  ('Austria', 'Tim Goyer', 69.3),
#  ('Austria', 'Dan Miller', 69.3),
#  ('Austria', 'Kathy Chase', 69.3),
#  ('Austria', 'Heather Leacock', 69.3),
#  ('Austria', 'John Gordon', 69.3),
#  ('Austria', 'Frank Ralston', 69.3),
#  ('Austria', 'Victor Stevens', 69.3),
#  ('Austria', 'Richard Cunningham', 69.3),
#  ('Austria', 'Patrick Gray', 69.3),
#  ('Austria', 'Julia Barnett', 69.3),
#  ('Austria', 'Robert Brown', 69.3),
#  ('Austria', 'Edward Francis', 69.3),
#  ('Austria', 'Martha Silk', 69.3),
#  ('Austria', 'Aaron Mitchell', 69.3),
#  ('Austria', 'Ellie Sullivan', 69.3),
#  ('Austria', 'João Fernandes', 69.3),
#  ('Austria', 'Madalena Sampaio', 69.3),
#  ('Austria', 'Hannah Schneider', 69.3),
#  ('Austria', 'Fynn Zimmermann', 69.3),
#  ('Austria', 'Niklas Schröder', 69.3),
#  ('Austria', 'Camille Bernard', 69.3),
#  ('Austria', 'Dominique Lefebvre', 69.3),
#  ('Austria', 'Marc Dubois', 69.3),
#  ('Austria', 'Wyatt Girard', 69.3),
#  ('Austria', 'Isabelle Mercier', 69.3),
#  ('Austria', 'Terhi Hämäläinen', 69.3),
#  ('Austria', 'Ladislav Kovács', 69.3),
#  ('Austria', "Hugh O'Reilly", 69.3),
#  ('Austria', 'Lucas Mancini', 69.3),
#  ('Austria', 'Johannes Van der Berg', 69.3),
#  ('Austria', 'Stanisław Wójcik', 69.3),
#  ('Austria', 'Enrique Muñoz', 69.3),
#  ('Austria', 'Joakim Johansson', 69.3),
#  ('Austria', 'Emma Jones', 69.3),
#  ('Austria', 'Phil Hughes', 69.3),
#  ('Austria', 'Steve Murray', 69.3),
#  ('Austria', 'Mark Taylor', 69.3),
#  ('Austria', 'Diego Gutiérrez', 69.3),
#  ('Austria', 'Luis Rojas', 69.3),
#  ('Austria', 'Manoj Pareek', 69.3),
#  ('Austria', 'Puja Srivastava', 69.3),
#  ('Belgium', 'Luís Gonçalves', 60.38999999999999),
#  ('Belgium', 'Leonie Köhler', 60.38999999999999),
#  ('Belgium', 'François Tremblay', 60.38999999999999),
#  ('Belgium', 'Bjørn Hansen', 60.38999999999999),
#  ('Belgium', 'František Wichterlová', 60.38999999999999),
#  ('Belgium', 'Helena Holý', 60.38999999999999),
#  ('Belgium', 'Astrid Gruber', 60.38999999999999),
#  ('Belgium', 'Daan Peeters', 60.38999999999999),
#  ('Belgium', 'Kara Nielsen', 60.38999999999999),
#  ('Belgium', 'Eduardo Martins', 60.38999999999999),
#  ('Belgium', 'Alexandre Rocha', 60.38999999999999),
#  ('Belgium', 'Roberto Almeida', 60.38999999999999),
#  ('Belgium', 'Fernanda Ramos', 60.38999999999999),
#  ('Belgium', 'Mark Philips', 60.38999999999999),
#  ('Belgium', 'Jennifer Peterson', 60.38999999999999),
#  ('Belgium', 'Frank Harris', 60.38999999999999),
#  ('Belgium', 'Jack Smith', 60.38999999999999),
#  ('Belgium', 'Michelle Brooks', 60.38999999999999),
#  ('Belgium', 'Tim Goyer', 60.38999999999999),
#  ('Belgium', 'Dan Miller', 60.38999999999999),
#  ('Belgium', 'Kathy Chase', 60.38999999999999),
#  ('Belgium', 'Heather Leacock', 60.38999999999999),
#  ('Belgium', 'John Gordon', 60.38999999999999),
#  ('Belgium', 'Frank Ralston', 60.38999999999999),
#  ('Belgium', 'Victor Stevens', 60.38999999999999),
#  ('Belgium', 'Richard Cunningham', 60.38999999999999),
#  ('Belgium', 'Patrick Gray', 60.38999999999999),
#  ('Belgium', 'Julia Barnett', 60.38999999999999),
#  ('Belgium', 'Robert Brown', 60.38999999999999),
#  ('Belgium', 'Edward Francis', 60.38999999999999),
#  ('Belgium', 'Martha Silk', 60.38999999999999),
#  ('Belgium', 'Aaron Mitchell', 60.38999999999999),
#  ('Belgium', 'Ellie Sullivan', 60.38999999999999),
#  ('Belgium', 'João Fernandes', 60.38999999999999),
#  ('Belgium', 'Madalena Sampaio', 60.38999999999999),
#  ('Belgium', 'Hannah Schneider', 60.38999999999999),
#  ('Belgium', 'Fynn Zimmermann', 60.38999999999999),
#  ('Belgium', 'Niklas Schröder', 60.38999999999999),
#  ('Belgium', 'Camille Bernard', 60.38999999999999),
#  ('Belgium', 'Dominique Lefebvre', 60.38999999999999),
#  ('Belgium', 'Marc Dubois', 60.38999999999999),
#  ('Belgium', 'Wyatt Girard', 60.38999999999999),
#  ('Belgium', 'Isabelle Mercier', 60.38999999999999),
#  ('Belgium', 'Terhi Hämäläinen', 60.38999999999999),
#  ('Belgium', 'Ladislav Kovács', 60.38999999999999),
#  ('Belgium', "Hugh O'Reilly", 60.38999999999999),
#  ('Belgium', 'Lucas Mancini', 60.38999999999999),
#  ('Belgium', 'Johannes Van der Berg', 60.38999999999999),
#  ('Belgium', 'Stanisław Wójcik', 60.38999999999999),
#  ('Belgium', 'Enrique Muñoz', 60.38999999999999),
#  ('Belgium', 'Joakim Johansson', 60.38999999999999),
#  ('Belgium', 'Emma Jones', 60.38999999999999),
#  ('Belgium', 'Phil Hughes', 60.38999999999999),
#  ('Belgium', 'Steve Murray', 60.38999999999999),
#  ('Belgium', 'Mark Taylor', 60.38999999999999),
#  ('Belgium', 'Diego Gutiérrez', 60.38999999999999),
#  ('Belgium', 'Luis Rojas', 60.38999999999999),
#  ('Belgium', 'Manoj Pareek', 60.38999999999999),
#  ('Belgium', 'Puja Srivastava', 60.38999999999999),
#  ('Brazil', 'Luís Gonçalves', 108.89999999999998),
#  ('Brazil', 'Leonie Köhler', 108.89999999999998),
#  ('Brazil', 'François Tremblay', 108.89999999999998),
#  ('Brazil', 'Bjørn Hansen', 108.89999999999998),
#  ('Brazil', 'František Wichterlová', 108.89999999999998),
#  ('Brazil', 'Helena Holý', 108.89999999999998),
#  ('Brazil', 'Astrid Gruber', 108.89999999999998),
#  ('Brazil', 'Daan Peeters', 108.89999999999998),
#  ('Brazil', 'Kara Nielsen', 108.89999999999998),
#  ('Brazil', 'Eduardo Martins', 108.89999999999998),
#  ('Brazil', 'Alexandre Rocha', 108.89999999999998),
#  ('Brazil', 'Roberto Almeida', 108.89999999999998),
#  ('Brazil', 'Fernanda Ramos', 108.89999999999998),
#  ('Brazil', 'Mark Philips', 108.89999999999998),
#  ('Brazil', 'Jennifer Peterson', 108.89999999999998),
#  ('Brazil', 'Frank Harris', 108.89999999999998),
#  ('Brazil', 'Jack Smith', 108.89999999999998),
#  ('Brazil', 'Michelle Brooks', 108.89999999999998),
#  ('Brazil', 'Tim Goyer', 108.89999999999998),
#  ('Brazil', 'Dan Miller', 108.89999999999998),
#  ('Brazil', 'Kathy Chase', 108.89999999999998),
#  ('Brazil', 'Heather Leacock', 108.89999999999998),
#  ('Brazil', 'John Gordon', 108.89999999999998),
#  ('Brazil', 'Frank Ralston', 108.89999999999998),
#  ('Brazil', 'Victor Stevens', 108.89999999999998),
#  ('Brazil', 'Richard Cunningham', 108.89999999999998),
#  ('Brazil', 'Patrick Gray', 108.89999999999998),
#  ('Brazil', 'Julia Barnett', 108.89999999999998),
#  ('Brazil', 'Robert Brown', 108.89999999999998),
#  ('Brazil', 'Edward Francis', 108.89999999999998),
#  ('Brazil', 'Martha Silk', 108.89999999999998),
#  ('Brazil', 'Aaron Mitchell', 108.89999999999998),
#  ('Brazil', 'Ellie Sullivan', 108.89999999999998),
#  ('Brazil', 'João Fernandes', 108.89999999999998),
#  ('Brazil', 'Madalena Sampaio', 108.89999999999998),
#  ('Brazil', 'Hannah Schneider', 108.89999999999998),
#  ('Brazil', 'Fynn Zimmermann', 108.89999999999998),
#  ('Brazil', 'Niklas Schröder', 108.89999999999998),
#  ('Brazil', 'Camille Bernard', 108.89999999999998),
#  ('Brazil', 'Dominique Lefebvre', 108.89999999999998),
#  ('Brazil', 'Marc Dubois', 108.89999999999998),
#  ('Brazil', 'Wyatt Girard', 108.89999999999998),
#  ('Brazil', 'Isabelle Mercier', 108.89999999999998),
#  ('Brazil', 'Terhi Hämäläinen', 108.89999999999998),
#  ('Brazil', 'Ladislav Kovács', 108.89999999999998),
#  ('Brazil', "Hugh O'Reilly", 108.89999999999998),
#  ('Brazil', 'Lucas Mancini', 108.89999999999998),
#  ('Brazil', 'Johannes Van der Berg', 108.89999999999998),
#  ('Brazil', 'Stanisław Wójcik', 108.89999999999998),
#  ('Brazil', 'Enrique Muñoz', 108.89999999999998),
#  ('Brazil', 'Joakim Johansson', 108.89999999999998),
#  ('Brazil', 'Emma Jones', 108.89999999999998),
#  ('Brazil', 'Phil Hughes', 108.89999999999998),
#  ('Brazil', 'Steve Murray', 108.89999999999998),
#  ('Brazil', 'Mark Taylor', 108.89999999999998),
#  ('Brazil', 'Diego Gutiérrez', 108.89999999999998),
#  ('Brazil', 'Luis Rojas', 108.89999999999998),
#  ('Brazil', 'Manoj Pareek', 108.89999999999998),
#  ('Brazil', 'Puja Srivastava', 108.89999999999998),
#  ('Canada', 'Luís Gonçalves', 99.99),
#  ('Canada', 'Leonie Köhler', 99.99),
#  ('Canada', 'François Tremblay', 99.99),
#  ('Canada', 'Bjørn Hansen', 99.99),
#  ('Canada', 'František Wichterlová', 99.99),
#  ('Canada', 'Helena Holý', 99.99),
#  ('Canada', 'Astrid Gruber', 99.99),
#  ('Canada', 'Daan Peeters', 99.99),
#  ('Canada', 'Kara Nielsen', 99.99),
#  ('Canada', 'Eduardo Martins', 99.99),
#  ('Canada', 'Alexandre Rocha', 99.99),
#  ('Canada', 'Roberto Almeida', 99.99),
#  ('Canada', 'Fernanda Ramos', 99.99),
#  ('Canada', 'Mark Philips', 99.99),
#  ('Canada', 'Jennifer Peterson', 99.99),
#  ('Canada', 'Frank Harris', 99.99),
#  ('Canada', 'Jack Smith', 99.99),
#  ('Canada', 'Michelle Brooks', 99.99),
#  ('Canada', 'Tim Goyer', 99.99),
#  ('Canada', 'Dan Miller', 99.99),
#  ('Canada', 'Kathy Chase', 99.99),
#  ('Canada', 'Heather Leacock', 99.99),
#  ('Canada', 'John Gordon', 99.99),
#  ('Canada', 'Frank Ralston', 99.99),
#  ('Canada', 'Victor Stevens', 99.99),
#  ('Canada', 'Richard Cunningham', 99.99),
#  ('Canada', 'Patrick Gray', 99.99),
#  ('Canada', 'Julia Barnett', 99.99),
#  ('Canada', 'Robert Brown', 99.99),
#  ('Canada', 'Edward Francis', 99.99),
#  ('Canada', 'Martha Silk', 99.99),
#  ('Canada', 'Aaron Mitchell', 99.99),
#  ('Canada', 'Ellie Sullivan', 99.99),
#  ('Canada', 'João Fernandes', 99.99),
#  ('Canada', 'Madalena Sampaio', 99.99),
#  ('Canada', 'Hannah Schneider', 99.99),
#  ('Canada', 'Fynn Zimmermann', 99.99),
#  ('Canada', 'Niklas Schröder', 99.99),
#  ('Canada', 'Camille Bernard', 99.99),
#  ('Canada', 'Dominique Lefebvre', 99.99),
#  ('Canada', 'Marc Dubois', 99.99),
#  ('Canada', 'Wyatt Girard', 99.99),
#  ('Canada', 'Isabelle Mercier', 99.99),
#  ('Canada', 'Terhi Hämäläinen', 99.99),
#  ('Canada', 'Ladislav Kovács', 99.99),
#  ('Canada', "Hugh O'Reilly", 99.99),
#  ('Canada', 'Lucas Mancini', 99.99),
#  ('Canada', 'Johannes Van der Berg', 99.99),
#  ('Canada', 'Stanisław Wójcik', 99.99),
#  ('Canada', 'Enrique Muñoz', 99.99),
#  ('Canada', 'Joakim Johansson', 99.99),
#  ('Canada', 'Emma Jones', 99.99),
#  ('Canada', 'Phil Hughes', 99.99),
#  ('Canada', 'Steve Murray', 99.99),
#  ('Canada', 'Mark Taylor', 99.99),
#  ('Canada', 'Diego Gutiérrez', 99.99),
#  ('Canada', 'Luis Rojas', 99.99),
#  ('Canada', 'Manoj Pareek', 99.99),
#  ('Canada', 'Puja Srivastava', 99.99),
#  ('Chile', 'Luís Gonçalves', 97.02000000000001),
#  ('Chile', 'Leonie Köhler', 97.02000000000001),
#  ('Chile', 'François Tremblay', 97.02000000000001),
#  ('Chile', 'Bjørn Hansen', 97.02000000000001),
#  ('Chile', 'František Wichterlová', 97.02000000000001),
#  ('Chile', 'Helena Holý', 97.02000000000001),
#  ('Chile', 'Astrid Gruber', 97.02000000000001),
#  ('Chile', 'Daan Peeters', 97.02000000000001),
#  ('Chile', 'Kara Nielsen', 97.02000000000001),
#  ('Chile', 'Eduardo Martins', 97.02000000000001),
#  ('Chile', 'Alexandre Rocha', 97.02000000000001),
#  ('Chile', 'Roberto Almeida', 97.02000000000001),
#  ('Chile', 'Fernanda Ramos', 97.02000000000001),
#  ('Chile', 'Mark Philips', 97.02000000000001),
#  ('Chile', 'Jennifer Peterson', 97.02000000000001),
#  ('Chile', 'Frank Harris', 97.02000000000001),
#  ('Chile', 'Jack Smith', 97.02000000000001),
#  ('Chile', 'Michelle Brooks', 97.02000000000001),
#  ('Chile', 'Tim Goyer', 97.02000000000001),
#  ('Chile', 'Dan Miller', 97.02000000000001),
#  ('Chile', 'Kathy Chase', 97.02000000000001),
#  ('Chile', 'Heather Leacock', 97.02000000000001),
#  ('Chile', 'John Gordon', 97.02000000000001),
#  ('Chile', 'Frank Ralston', 97.02000000000001),
#  ('Chile', 'Victor Stevens', 97.02000000000001),
#  ('Chile', 'Richard Cunningham', 97.02000000000001),
#  ('Chile', 'Patrick Gray', 97.02000000000001),
#  ('Chile', 'Julia Barnett', 97.02000000000001),
#  ('Chile', 'Robert Brown', 97.02000000000001),
#  ('Chile', 'Edward Francis', 97.02000000000001),
#  ('Chile', 'Martha Silk', 97.02000000000001),
#  ('Chile', 'Aaron Mitchell', 97.02000000000001),
#  ('Chile', 'Ellie Sullivan', 97.02000000000001),
#  ('Chile', 'João Fernandes', 97.02000000000001),
#  ('Chile', 'Madalena Sampaio', 97.02000000000001),
#  ('Chile', 'Hannah Schneider', 97.02000000000001),
#  ('Chile', 'Fynn Zimmermann', 97.02000000000001),
#  ('Chile', 'Niklas Schröder', 97.02000000000001),
#  ('Chile', 'Camille Bernard', 97.02000000000001),
#  ('Chile', 'Dominique Lefebvre', 97.02000000000001),
#  ('Chile', 'Marc Dubois', 97.02000000000001),
#  ('Chile', 'Wyatt Girard', 97.02000000000001),
#  ('Chile', 'Isabelle Mercier', 97.02000000000001),
#  ('Chile', 'Terhi Hämäläinen', 97.02000000000001),
#  ('Chile', 'Ladislav Kovács', 97.02000000000001),
#  ('Chile', "Hugh O'Reilly", 97.02000000000001),
#  ('Chile', 'Lucas Mancini', 97.02000000000001),
#  ('Chile', 'Johannes Van der Berg', 97.02000000000001),
#  ('Chile', 'Stanisław Wójcik', 97.02000000000001),
#  ('Chile', 'Enrique Muñoz', 97.02000000000001),
#  ('Chile', 'Joakim Johansson', 97.02000000000001),
#  ('Chile', 'Emma Jones', 97.02000000000001),
#  ('Chile', 'Phil Hughes', 97.02000000000001),
#  ('Chile', 'Steve Murray', 97.02000000000001),
#  ('Chile', 'Mark Taylor', 97.02000000000001),
#  ('Chile', 'Diego Gutiérrez', 97.02000000000001),
#  ('Chile', 'Luis Rojas', 97.02000000000001),
#  ('Chile', 'Manoj Pareek', 97.02000000000001),
#  ('Chile', 'Puja Srivastava', 97.02000000000001),
#  ('Czech Republic', 'Luís Gonçalves', 144.54000000000002),
#  ('Czech Republic', 'Leonie Köhler', 144.54000000000002),
#  ('Czech Republic', 'François Tremblay', 144.54000000000002),
#  ('Czech Republic', 'Bjørn Hansen', 144.54000000000002),
#  ('Czech Republic', 'František Wichterlová', 144.54000000000002),
#  ('Czech Republic', 'Helena Holý', 144.54000000000002),
#  ('Czech Republic', 'Astrid Gruber', 144.54000000000002),
#  ('Czech Republic', 'Daan Peeters', 144.54000000000002),
#  ('Czech Republic', 'Kara Nielsen', 144.54000000000002),
#  ('Czech Republic', 'Eduardo Martins', 144.54000000000002),
#  ('Czech Republic', 'Alexandre Rocha', 144.54000000000002),
#  ('Czech Republic', 'Roberto Almeida', 144.54000000000002),
#  ('Czech Republic', 'Fernanda Ramos', 144.54000000000002),
#  ('Czech Republic', 'Mark Philips', 144.54000000000002),
#  ('Czech Republic', 'Jennifer Peterson', 144.54000000000002),
#  ('Czech Republic', 'Frank Harris', 144.54000000000002),
#  ('Czech Republic', 'Jack Smith', 144.54000000000002),
#  ('Czech Republic', 'Michelle Brooks', 144.54000000000002),
#  ('Czech Republic', 'Tim Goyer', 144.54000000000002),
#  ('Czech Republic', 'Dan Miller', 144.54000000000002),
#  ('Czech Republic', 'Kathy Chase', 144.54000000000002),
#  ('Czech Republic', 'Heather Leacock', 144.54000000000002),
#  ('Czech Republic', 'John Gordon', 144.54000000000002),
#  ('Czech Republic', 'Frank Ralston', 144.54000000000002),
#  ('Czech Republic', 'Victor Stevens', 144.54000000000002),
#  ('Czech Republic', 'Richard Cunningham', 144.54000000000002),
#  ('Czech Republic', 'Patrick Gray', 144.54000000000002),
#  ('Czech Republic', 'Julia Barnett', 144.54000000000002),
#  ('Czech Republic', 'Robert Brown', 144.54000000000002),
#  ('Czech Republic', 'Edward Francis', 144.54000000000002),
#  ('Czech Republic', 'Martha Silk', 144.54000000000002),
#  ('Czech Republic', 'Aaron Mitchell', 144.54000000000002),
#  ('Czech Republic', 'Ellie Sullivan', 144.54000000000002),
#  ('Czech Republic', 'João Fernandes', 144.54000000000002),
#  ('Czech Republic', 'Madalena Sampaio', 144.54000000000002),
#  ('Czech Republic', 'Hannah Schneider', 144.54000000000002),
#  ('Czech Republic', 'Fynn Zimmermann', 144.54000000000002),
#  ('Czech Republic', 'Niklas Schröder', 144.54000000000002),
#  ('Czech Republic', 'Camille Bernard', 144.54000000000002),
#  ('Czech Republic', 'Dominique Lefebvre', 144.54000000000002),
#  ('Czech Republic', 'Marc Dubois', 144.54000000000002),
#  ('Czech Republic', 'Wyatt Girard', 144.54000000000002),
#  ('Czech Republic', 'Isabelle Mercier', 144.54000000000002),
#  ('Czech Republic', 'Terhi Hämäläinen', 144.54000000000002),
#  ('Czech Republic', 'Ladislav Kovács', 144.54000000000002),
#  ('Czech Republic', "Hugh O'Reilly", 144.54000000000002),
#  ('Czech Republic', 'Lucas Mancini', 144.54000000000002),
#  ('Czech Republic', 'Johannes Van der Berg', 144.54000000000002),
#  ('Czech Republic', 'Stanisław Wójcik', 144.54000000000002),
#  ('Czech Republic', 'Enrique Muñoz', 144.54000000000002),
#  ('Czech Republic', 'Joakim Johansson', 144.54000000000002),
#  ('Czech Republic', 'Emma Jones', 144.54000000000002),
#  ('Czech Republic', 'Phil Hughes', 144.54000000000002),
#  ('Czech Republic', 'Steve Murray', 144.54000000000002),
#  ('Czech Republic', 'Mark Taylor', 144.54000000000002),
#  ('Czech Republic', 'Diego Gutiérrez', 144.54000000000002),
#  ('Czech Republic', 'Luis Rojas', 144.54000000000002),
#  ('Czech Republic', 'Manoj Pareek', 144.54000000000002),
#  ('Czech Republic', 'Puja Srivastava', 144.54000000000002),
#  ('Denmark', 'Luís Gonçalves', 37.61999999999999),
#  ('Denmark', 'Leonie Köhler', 37.61999999999999),
#  ('Denmark', 'François Tremblay', 37.61999999999999),
#  ('Denmark', 'Bjørn Hansen', 37.61999999999999),
#  ('Denmark', 'František Wichterlová', 37.61999999999999),
#  ('Denmark', 'Helena Holý', 37.61999999999999),
#  ('Denmark', 'Astrid Gruber', 37.61999999999999),
#  ('Denmark', 'Daan Peeters', 37.61999999999999),
#  ('Denmark', 'Kara Nielsen', 37.61999999999999),
#  ('Denmark', 'Eduardo Martins', 37.61999999999999),
#  ('Denmark', 'Alexandre Rocha', 37.61999999999999),
#  ('Denmark', 'Roberto Almeida', 37.61999999999999),
#  ('Denmark', 'Fernanda Ramos', 37.61999999999999),
#  ('Denmark', 'Mark Philips', 37.61999999999999),
#  ('Denmark', 'Jennifer Peterson', 37.61999999999999),
#  ('Denmark', 'Frank Harris', 37.61999999999999),
#  ('Denmark', 'Jack Smith', 37.61999999999999),
#  ('Denmark', 'Michelle Brooks', 37.61999999999999),
#  ('Denmark', 'Tim Goyer', 37.61999999999999),
#  ('Denmark', 'Dan Miller', 37.61999999999999),
#  ('Denmark', 'Kathy Chase', 37.61999999999999),
#  ('Denmark', 'Heather Leacock', 37.61999999999999),
#  ('Denmark', 'John Gordon', 37.61999999999999),
#  ('Denmark', 'Frank Ralston', 37.61999999999999),
#  ('Denmark', 'Victor Stevens', 37.61999999999999),
#  ('Denmark', 'Richard Cunningham', 37.61999999999999),
#  ('Denmark', 'Patrick Gray', 37.61999999999999),
#  ('Denmark', 'Julia Barnett', 37.61999999999999),
#  ('Denmark', 'Robert Brown', 37.61999999999999),
#  ('Denmark', 'Edward Francis', 37.61999999999999),
#  ('Denmark', 'Martha Silk', 37.61999999999999),
#  ('Denmark', 'Aaron Mitchell', 37.61999999999999),
#  ('Denmark', 'Ellie Sullivan', 37.61999999999999),
#  ('Denmark', 'João Fernandes', 37.61999999999999),
#  ('Denmark', 'Madalena Sampaio', 37.61999999999999),
#  ('Denmark', 'Hannah Schneider', 37.61999999999999),
#  ('Denmark', 'Fynn Zimmermann', 37.61999999999999),
#  ('Denmark', 'Niklas Schröder', 37.61999999999999),
#  ('Denmark', 'Camille Bernard', 37.61999999999999),
#  ('Denmark', 'Dominique Lefebvre', 37.61999999999999),
#  ('Denmark', 'Marc Dubois', 37.61999999999999),
#  ('Denmark', 'Wyatt Girard', 37.61999999999999),
#  ('Denmark', 'Isabelle Mercier', 37.61999999999999),
#  ('Denmark', 'Terhi Hämäläinen', 37.61999999999999),
#  ('Denmark', 'Ladislav Kovács', 37.61999999999999),
#  ('Denmark', "Hugh O'Reilly", 37.61999999999999),
#  ('Denmark', 'Lucas Mancini', 37.61999999999999),
#  ('Denmark', 'Johannes Van der Berg', 37.61999999999999),
#  ('Denmark', 'Stanisław Wójcik', 37.61999999999999),
#  ('Denmark', 'Enrique Muñoz', 37.61999999999999),
#  ('Denmark', 'Joakim Johansson', 37.61999999999999),
#  ('Denmark', 'Emma Jones', 37.61999999999999),
#  ('Denmark', 'Phil Hughes', 37.61999999999999),
#  ('Denmark', 'Steve Murray', 37.61999999999999),
#  ('Denmark', 'Mark Taylor', 37.61999999999999),
#  ('Denmark', 'Diego Gutiérrez', 37.61999999999999),
#  ('Denmark', 'Luis Rojas', 37.61999999999999),
#  ('Denmark', 'Manoj Pareek', 37.61999999999999),
#  ('Denmark', 'Puja Srivastava', 37.61999999999999),
#  ('Finland', 'Luís Gonçalves', 79.2),
#  ('Finland', 'Leonie Köhler', 79.2),
#  ('Finland', 'François Tremblay', 79.2),
#  ('Finland', 'Bjørn Hansen', 79.2),
#  ('Finland', 'František Wichterlová', 79.2),
#  ('Finland', 'Helena Holý', 79.2),
#  ('Finland', 'Astrid Gruber', 79.2),
#  ('Finland', 'Daan Peeters', 79.2),
#  ('Finland', 'Kara Nielsen', 79.2),
#  ('Finland', 'Eduardo Martins', 79.2),
#  ('Finland', 'Alexandre Rocha', 79.2),
#  ('Finland', 'Roberto Almeida', 79.2),
#  ('Finland', 'Fernanda Ramos', 79.2),
#  ('Finland', 'Mark Philips', 79.2),
#  ('Finland', 'Jennifer Peterson', 79.2),
#  ('Finland', 'Frank Harris', 79.2),
#  ('Finland', 'Jack Smith', 79.2),
#  ('Finland', 'Michelle Brooks', 79.2),
#  ('Finland', 'Tim Goyer', 79.2),
#  ('Finland', 'Dan Miller', 79.2),
#  ('Finland', 'Kathy Chase', 79.2),
#  ('Finland', 'Heather Leacock', 79.2),
#  ('Finland', 'John Gordon', 79.2),
#  ('Finland', 'Frank Ralston', 79.2),
#  ('Finland', 'Victor Stevens', 79.2),
#  ('Finland', 'Richard Cunningham', 79.2),
#  ('Finland', 'Patrick Gray', 79.2),
#  ('Finland', 'Julia Barnett', 79.2),
#  ('Finland', 'Robert Brown', 79.2),
#  ('Finland', 'Edward Francis', 79.2),
#  ('Finland', 'Martha Silk', 79.2),
#  ('Finland', 'Aaron Mitchell', 79.2),
#  ('Finland', 'Ellie Sullivan', 79.2),
#  ('Finland', 'João Fernandes', 79.2),
#  ('Finland', 'Madalena Sampaio', 79.2),
#  ('Finland', 'Hannah Schneider', 79.2),
#  ('Finland', 'Fynn Zimmermann', 79.2),
#  ('Finland', 'Niklas Schröder', 79.2),
#  ('Finland', 'Camille Bernard', 79.2),
#  ('Finland', 'Dominique Lefebvre', 79.2),
#  ('Finland', 'Marc Dubois', 79.2),
#  ('Finland', 'Wyatt Girard', 79.2),
#  ('Finland', 'Isabelle Mercier', 79.2),
#  ('Finland', 'Terhi Hämäläinen', 79.2),
#  ('Finland', 'Ladislav Kovács', 79.2),
#  ('Finland', "Hugh O'Reilly", 79.2),
#  ('Finland', 'Lucas Mancini', 79.2),
#  ('Finland', 'Johannes Van der Berg', 79.2),
#  ('Finland', 'Stanisław Wójcik', 79.2),
#  ('Finland', 'Enrique Muñoz', 79.2),
#  ('Finland', 'Joakim Johansson', 79.2),
#  ('Finland', 'Emma Jones', 79.2),
#  ('Finland', 'Phil Hughes', 79.2),
#  ('Finland', 'Steve Murray', 79.2),
#  ('Finland', 'Mark Taylor', 79.2),
#  ('Finland', 'Diego Gutiérrez', 79.2),
#  ('Finland', 'Luis Rojas', 79.2),
#  ('Finland', 'Manoj Pareek', 79.2),
#  ('Finland', 'Puja Srivastava', 79.2),
#  ('France', 'Luís Gonçalves', 99.99),
#  ('France', 'Leonie Köhler', 99.99),
#  ('France', 'François Tremblay', 99.99),
#  ('France', 'Bjørn Hansen', 99.99),
#  ('France', 'František Wichterlová', 99.99),
#  ('France', 'Helena Holý', 99.99),
#  ('France', 'Astrid Gruber', 99.99),
#  ('France', 'Daan Peeters', 99.99),
#  ('France', 'Kara Nielsen', 99.99),
#  ('France', 'Eduardo Martins', 99.99),
#  ('France', 'Alexandre Rocha', 99.99),
#  ('France', 'Roberto Almeida', 99.99),
#  ('France', 'Fernanda Ramos', 99.99),
#  ('France', 'Mark Philips', 99.99),
#  ('France', 'Jennifer Peterson', 99.99),
#  ('France', 'Frank Harris', 99.99),
#  ('France', 'Jack Smith', 99.99),
#  ('France', 'Michelle Brooks', 99.99),
#  ('France', 'Tim Goyer', 99.99),
#  ('France', 'Dan Miller', 99.99),
#  ('France', 'Kathy Chase', 99.99),
#  ('France', 'Heather Leacock', 99.99),
#  ('France', 'John Gordon', 99.99),
#  ('France', 'Frank Ralston', 99.99),
#  ('France', 'Victor Stevens', 99.99),
#  ('France', 'Richard Cunningham', 99.99),
#  ('France', 'Patrick Gray', 99.99),
#  ('France', 'Julia Barnett', 99.99),
#  ('France', 'Robert Brown', 99.99),
#  ('France', 'Edward Francis', 99.99),
#  ('France', 'Martha Silk', 99.99),
#  ('France', 'Aaron Mitchell', 99.99),
#  ('France', 'Ellie Sullivan', 99.99),
#  ('France', 'João Fernandes', 99.99),
#  ('France', 'Madalena Sampaio', 99.99),
#  ('France', 'Hannah Schneider', 99.99),
#  ('France', 'Fynn Zimmermann', 99.99),
#  ('France', 'Niklas Schröder', 99.99),
#  ('France', 'Camille Bernard', 99.99),
#  ('France', 'Dominique Lefebvre', 99.99),
#  ('France', 'Marc Dubois', 99.99),
#  ('France', 'Wyatt Girard', 99.99),
#  ('France', 'Isabelle Mercier', 99.99),
#  ('France', 'Terhi Hämäläinen', 99.99),
#  ('France', 'Ladislav Kovács', 99.99),
#  ('France', "Hugh O'Reilly", 99.99),
#  ('France', 'Lucas Mancini', 99.99),
#  ('France', 'Johannes Van der Berg', 99.99),
#  ('France', 'Stanisław Wójcik', 99.99),
#  ('France', 'Enrique Muñoz', 99.99),
#  ('France', 'Joakim Johansson', 99.99),
#  ('France', 'Emma Jones', 99.99),
#  ('France', 'Phil Hughes', 99.99),
#  ('France', 'Steve Murray', 99.99),
#  ('France', 'Mark Taylor', 99.99),
#  ('France', 'Diego Gutiérrez', 99.99),
#  ('France', 'Luis Rojas', 99.99),
#  ('France', 'Manoj Pareek', 99.99),
#  ('France', 'Puja Srivastava', 99.99),
#  ('Germany', 'Luís Gonçalves', 94.05000000000001),
#  ('Germany', 'Leonie Köhler', 94.05000000000001),
#  ('Germany', 'François Tremblay', 94.05000000000001),
#  ('Germany', 'Bjørn Hansen', 94.05000000000001),
#  ('Germany', 'František Wichterlová', 94.05000000000001),
#  ('Germany', 'Helena Holý', 94.05000000000001),
#  ('Germany', 'Astrid Gruber', 94.05000000000001),
#  ('Germany', 'Daan Peeters', 94.05000000000001),
#  ('Germany', 'Kara Nielsen', 94.05000000000001),
#  ('Germany', 'Eduardo Martins', 94.05000000000001),
#  ('Germany', 'Alexandre Rocha', 94.05000000000001),
#  ('Germany', 'Roberto Almeida', 94.05000000000001),
#  ('Germany', 'Fernanda Ramos', 94.05000000000001),
#  ('Germany', 'Mark Philips', 94.05000000000001),
#  ('Germany', 'Jennifer Peterson', 94.05000000000001),
#  ('Germany', 'Frank Harris', 94.05000000000001),
#  ('Germany', 'Jack Smith', 94.05000000000001),
#  ('Germany', 'Michelle Brooks', 94.05000000000001),
#  ('Germany', 'Tim Goyer', 94.05000000000001),
#  ('Germany', 'Dan Miller', 94.05000000000001),
#  ('Germany', 'Kathy Chase', 94.05000000000001),
#  ('Germany', 'Heather Leacock', 94.05000000000001),
#  ('Germany', 'John Gordon', 94.05000000000001),
#  ('Germany', 'Frank Ralston', 94.05000000000001),
#  ('Germany', 'Victor Stevens', 94.05000000000001),
#  ('Germany', 'Richard Cunningham', 94.05000000000001),
#  ('Germany', 'Patrick Gray', 94.05000000000001),
#  ('Germany', 'Julia Barnett', 94.05000000000001),
#  ('Germany', 'Robert Brown', 94.05000000000001),
#  ('Germany', 'Edward Francis', 94.05000000000001),
#  ('Germany', 'Martha Silk', 94.05000000000001),
#  ('Germany', 'Aaron Mitchell', 94.05000000000001),
#  ('Germany', 'Ellie Sullivan', 94.05000000000001),
#  ('Germany', 'João Fernandes', 94.05000000000001),
#  ('Germany', 'Madalena Sampaio', 94.05000000000001),
#  ('Germany', 'Hannah Schneider', 94.05000000000001),
#  ('Germany', 'Fynn Zimmermann', 94.05000000000001),
#  ('Germany', 'Niklas Schröder', 94.05000000000001),
#  ('Germany', 'Camille Bernard', 94.05000000000001),
#  ('Germany', 'Dominique Lefebvre', 94.05000000000001),
#  ('Germany', 'Marc Dubois', 94.05000000000001),
#  ('Germany', 'Wyatt Girard', 94.05000000000001),
#  ('Germany', 'Isabelle Mercier', 94.05000000000001),
#  ('Germany', 'Terhi Hämäläinen', 94.05000000000001),
#  ('Germany', 'Ladislav Kovács', 94.05000000000001),
#  ('Germany', "Hugh O'Reilly", 94.05000000000001),
#  ('Germany', 'Lucas Mancini', 94.05000000000001),
#  ('Germany', 'Johannes Van der Berg', 94.05000000000001),
#  ('Germany', 'Stanisław Wójcik', 94.05000000000001),
#  ('Germany', 'Enrique Muñoz', 94.05000000000001),
#  ('Germany', 'Joakim Johansson', 94.05000000000001),
#  ('Germany', 'Emma Jones', 94.05000000000001),
#  ('Germany', 'Phil Hughes', 94.05000000000001),
#  ('Germany', 'Steve Murray', 94.05000000000001),
#  ('Germany', 'Mark Taylor', 94.05000000000001),
#  ('Germany', 'Diego Gutiérrez', 94.05000000000001),
#  ('Germany', 'Luis Rojas', 94.05000000000001),
#  ('Germany', 'Manoj Pareek', 94.05000000000001),
#  ('Germany', 'Puja Srivastava', 94.05000000000001),
#  ('Hungary', 'Luís Gonçalves', 78.21),
#  ('Hungary', 'Leonie Köhler', 78.21),
#  ('Hungary', 'François Tremblay', 78.21),
#  ('Hungary', 'Bjørn Hansen', 78.21),
#  ('Hungary', 'František Wichterlová', 78.21),
#  ('Hungary', 'Helena Holý', 78.21),
#  ('Hungary', 'Astrid Gruber', 78.21),
#  ('Hungary', 'Daan Peeters', 78.21),
#  ('Hungary', 'Kara Nielsen', 78.21),
#  ('Hungary', 'Eduardo Martins', 78.21),
#  ('Hungary', 'Alexandre Rocha', 78.21),
#  ('Hungary', 'Roberto Almeida', 78.21),
#  ('Hungary', 'Fernanda Ramos', 78.21),
#  ('Hungary', 'Mark Philips', 78.21),
#  ('Hungary', 'Jennifer Peterson', 78.21),
#  ('Hungary', 'Frank Harris', 78.21),
#  ('Hungary', 'Jack Smith', 78.21),
#  ('Hungary', 'Michelle Brooks', 78.21),
#  ('Hungary', 'Tim Goyer', 78.21),
#  ('Hungary', 'Dan Miller', 78.21),
#  ('Hungary', 'Kathy Chase', 78.21),
#  ('Hungary', 'Heather Leacock', 78.21),
#  ('Hungary', 'John Gordon', 78.21),
#  ('Hungary', 'Frank Ralston', 78.21),
#  ('Hungary', 'Victor Stevens', 78.21),
#  ('Hungary', 'Richard Cunningham', 78.21),
#  ('Hungary', 'Patrick Gray', 78.21),
#  ('Hungary', 'Julia Barnett', 78.21),
#  ('Hungary', 'Robert Brown', 78.21),
#  ('Hungary', 'Edward Francis', 78.21),
#  ('Hungary', 'Martha Silk', 78.21),
#  ('Hungary', 'Aaron Mitchell', 78.21),
#  ('Hungary', 'Ellie Sullivan', 78.21),
#  ('Hungary', 'João Fernandes', 78.21),
#  ('Hungary', 'Madalena Sampaio', 78.21),
#  ('Hungary', 'Hannah Schneider', 78.21),
#  ('Hungary', 'Fynn Zimmermann', 78.21),
#  ('Hungary', 'Niklas Schröder', 78.21),
#  ('Hungary', 'Camille Bernard', 78.21),
#  ('Hungary', 'Dominique Lefebvre', 78.21),
#  ('Hungary', 'Marc Dubois', 78.21),
#  ('Hungary', 'Wyatt Girard', 78.21),
#  ('Hungary', 'Isabelle Mercier', 78.21),
#  ('Hungary', 'Terhi Hämäläinen', 78.21),
#  ('Hungary', 'Ladislav Kovács', 78.21),
#  ('Hungary', "Hugh O'Reilly", 78.21),
#  ('Hungary', 'Lucas Mancini', 78.21),
#  ('Hungary', 'Johannes Van der Berg', 78.21),
#  ('Hungary', 'Stanisław Wójcik', 78.21),
#  ('Hungary', 'Enrique Muñoz', 78.21),
#  ('Hungary', 'Joakim Johansson', 78.21),
#  ('Hungary', 'Emma Jones', 78.21),
#  ('Hungary', 'Phil Hughes', 78.21),
#  ('Hungary', 'Steve Murray', 78.21),
#  ('Hungary', 'Mark Taylor', 78.21),
#  ('Hungary', 'Diego Gutiérrez', 78.21),
#  ('Hungary', 'Luis Rojas', 78.21),
#  ('Hungary', 'Manoj Pareek', 78.21),
#  ('Hungary', 'Puja Srivastava', 78.21),
#  ('India', 'Luís Gonçalves', 111.86999999999999),
#  ('India', 'Leonie Köhler', 111.86999999999999),
#  ('India', 'François Tremblay', 111.86999999999999),
#  ('India', 'Bjørn Hansen', 111.86999999999999),
#  ('India', 'František Wichterlová', 111.86999999999999),
#  ('India', 'Helena Holý', 111.86999999999999),
#  ('India', 'Astrid Gruber', 111.86999999999999),
#  ('India', 'Daan Peeters', 111.86999999999999),
#  ('India', 'Kara Nielsen', 111.86999999999999),
#  ('India', 'Eduardo Martins', 111.86999999999999),
#  ('India', 'Alexandre Rocha', 111.86999999999999),
#  ('India', 'Roberto Almeida', 111.86999999999999),
#  ('India', 'Fernanda Ramos', 111.86999999999999),
#  ('India', 'Mark Philips', 111.86999999999999),
#  ('India', 'Jennifer Peterson', 111.86999999999999),
#  ('India', 'Frank Harris', 111.86999999999999),
#  ('India', 'Jack Smith', 111.86999999999999),
#  ('India', 'Michelle Brooks', 111.86999999999999),
#  ('India', 'Tim Goyer', 111.86999999999999),
#  ('India', 'Dan Miller', 111.86999999999999),
#  ('India', 'Kathy Chase', 111.86999999999999),
#  ('India', 'Heather Leacock', 111.86999999999999),
#  ('India', 'John Gordon', 111.86999999999999),
#  ('India', 'Frank Ralston', 111.86999999999999),
#  ('India', 'Victor Stevens', 111.86999999999999),
#  ('India', 'Richard Cunningham', 111.86999999999999),
#  ('India', 'Patrick Gray', 111.86999999999999),
#  ('India', 'Julia Barnett', 111.86999999999999),
#  ('India', 'Robert Brown', 111.86999999999999),
#  ('India', 'Edward Francis', 111.86999999999999),
#  ('India', 'Martha Silk', 111.86999999999999),
#  ('India', 'Aaron Mitchell', 111.86999999999999),
#  ('India', 'Ellie Sullivan', 111.86999999999999),
#  ('India', 'João Fernandes', 111.86999999999999),
#  ('India', 'Madalena Sampaio', 111.86999999999999),
#  ('India', 'Hannah Schneider', 111.86999999999999),
#  ('India', 'Fynn Zimmermann', 111.86999999999999),
#  ('India', 'Niklas Schröder', 111.86999999999999),
#  ('India', 'Camille Bernard', 111.86999999999999),
#  ('India', 'Dominique Lefebvre', 111.86999999999999),
#  ('India', 'Marc Dubois', 111.86999999999999),
#  ('India', 'Wyatt Girard', 111.86999999999999),
#  ('India', 'Isabelle Mercier', 111.86999999999999),
#  ('India', 'Terhi Hämäläinen', 111.86999999999999),
#  ('India', 'Ladislav Kovács', 111.86999999999999),
#  ('India', "Hugh O'Reilly", 111.86999999999999),
#  ('India', 'Lucas Mancini', 111.86999999999999),
#  ('India', 'Johannes Van der Berg', 111.86999999999999),
#  ('India', 'Stanisław Wójcik', 111.86999999999999),
#  ('India', 'Enrique Muñoz', 111.86999999999999),
#  ('India', 'Joakim Johansson', 111.86999999999999),
#  ('India', 'Emma Jones', 111.86999999999999),
#  ('India', 'Phil Hughes', 111.86999999999999),
#  ('India', 'Steve Murray', 111.86999999999999),
#  ('India', 'Mark Taylor', 111.86999999999999),
#  ('India', 'Diego Gutiérrez', 111.86999999999999),
#  ('India', 'Luis Rojas', 111.86999999999999),
#  ('India', 'Manoj Pareek', 111.86999999999999),
#  ('India', 'Puja Srivastava', 111.86999999999999),
#  ('Ireland', 'Luís Gonçalves', 114.83999999999997),
#  ('Ireland', 'Leonie Köhler', 114.83999999999997),
#  ('Ireland', 'François Tremblay', 114.83999999999997),
#  ('Ireland', 'Bjørn Hansen', 114.83999999999997),
#  ('Ireland', 'František Wichterlová', 114.83999999999997),
#  ('Ireland', 'Helena Holý', 114.83999999999997),
#  ('Ireland', 'Astrid Gruber', 114.83999999999997),
#  ('Ireland', 'Daan Peeters', 114.83999999999997),
#  ('Ireland', 'Kara Nielsen', 114.83999999999997),
#  ('Ireland', 'Eduardo Martins', 114.83999999999997),
#  ('Ireland', 'Alexandre Rocha', 114.83999999999997),
#  ('Ireland', 'Roberto Almeida', 114.83999999999997),
#  ('Ireland', 'Fernanda Ramos', 114.83999999999997),
#  ('Ireland', 'Mark Philips', 114.83999999999997),
#  ('Ireland', 'Jennifer Peterson', 114.83999999999997),
#  ('Ireland', 'Frank Harris', 114.83999999999997),
#  ('Ireland', 'Jack Smith', 114.83999999999997),
#  ('Ireland', 'Michelle Brooks', 114.83999999999997),
#  ('Ireland', 'Tim Goyer', 114.83999999999997),
#  ('Ireland', 'Dan Miller', 114.83999999999997),
#  ('Ireland', 'Kathy Chase', 114.83999999999997),
#  ('Ireland', 'Heather Leacock', 114.83999999999997),
#  ('Ireland', 'John Gordon', 114.83999999999997),
#  ('Ireland', 'Frank Ralston', 114.83999999999997),
#  ('Ireland', 'Victor Stevens', 114.83999999999997),
#  ('Ireland', 'Richard Cunningham', 114.83999999999997),
#  ('Ireland', 'Patrick Gray', 114.83999999999997),
#  ('Ireland', 'Julia Barnett', 114.83999999999997),
#  ('Ireland', 'Robert Brown', 114.83999999999997),
#  ('Ireland', 'Edward Francis', 114.83999999999997),
#  ('Ireland', 'Martha Silk', 114.83999999999997),
#  ('Ireland', 'Aaron Mitchell', 114.83999999999997),
#  ('Ireland', 'Ellie Sullivan', 114.83999999999997),
#  ('Ireland', 'João Fernandes', 114.83999999999997),
#  ('Ireland', 'Madalena Sampaio', 114.83999999999997),
#  ('Ireland', 'Hannah Schneider', 114.83999999999997),
#  ('Ireland', 'Fynn Zimmermann', 114.83999999999997),
#  ('Ireland', 'Niklas Schröder', 114.83999999999997),
#  ('Ireland', 'Camille Bernard', 114.83999999999997),
#  ('Ireland', 'Dominique Lefebvre', 114.83999999999997),
#  ('Ireland', 'Marc Dubois', 114.83999999999997),
#  ('Ireland', 'Wyatt Girard', 114.83999999999997),
#  ('Ireland', 'Isabelle Mercier', 114.83999999999997),
#  ('Ireland', 'Terhi Hämäläinen', 114.83999999999997),
#  ('Ireland', 'Ladislav Kovács', 114.83999999999997),
#  ('Ireland', "Hugh O'Reilly", 114.83999999999997),
#  ('Ireland', 'Lucas Mancini', 114.83999999999997),
#  ('Ireland', 'Johannes Van der Berg', 114.83999999999997),
#  ('Ireland', 'Stanisław Wójcik', 114.83999999999997),
#  ('Ireland', 'Enrique Muñoz', 114.83999999999997),
#  ('Ireland', 'Joakim Johansson', 114.83999999999997),
#  ('Ireland', 'Emma Jones', 114.83999999999997),
#  ('Ireland', 'Phil Hughes', 114.83999999999997),
#  ('Ireland', 'Steve Murray', 114.83999999999997),
#  ('Ireland', 'Mark Taylor', 114.83999999999997),
#  ('Ireland', 'Diego Gutiérrez', 114.83999999999997),
#  ('Ireland', 'Luis Rojas', 114.83999999999997),
#  ('Ireland', 'Manoj Pareek', 114.83999999999997),
#  ('Ireland', 'Puja Srivastava', 114.83999999999997),
#  ('Italy', 'Luís Gonçalves', 50.49),
#  ('Italy', 'Leonie Köhler', 50.49),
#  ('Italy', 'François Tremblay', 50.49),
#  ('Italy', 'Bjørn Hansen', 50.49),
#  ('Italy', 'František Wichterlová', 50.49),
#  ('Italy', 'Helena Holý', 50.49),
#  ('Italy', 'Astrid Gruber', 50.49),
#  ('Italy', 'Daan Peeters', 50.49),
#  ('Italy', 'Kara Nielsen', 50.49),
#  ('Italy', 'Eduardo Martins', 50.49),
#  ('Italy', 'Alexandre Rocha', 50.49),
#  ('Italy', 'Roberto Almeida', 50.49),
#  ('Italy', 'Fernanda Ramos', 50.49),
#  ('Italy', 'Mark Philips', 50.49),
#  ('Italy', 'Jennifer Peterson', 50.49),
#  ('Italy', 'Frank Harris', 50.49),
#  ('Italy', 'Jack Smith', 50.49),
#  ('Italy', 'Michelle Brooks', 50.49),
#  ('Italy', 'Tim Goyer', 50.49),
#  ('Italy', 'Dan Miller', 50.49),
#  ('Italy', 'Kathy Chase', 50.49),
#  ('Italy', 'Heather Leacock', 50.49),
#  ('Italy', 'John Gordon', 50.49),
#  ('Italy', 'Frank Ralston', 50.49),
#  ('Italy', 'Victor Stevens', 50.49),
#  ('Italy', 'Richard Cunningham', 50.49),
#  ('Italy', 'Patrick Gray', 50.49),
#  ('Italy', 'Julia Barnett', 50.49),
#  ('Italy', 'Robert Brown', 50.49),
#  ('Italy', 'Edward Francis', 50.49),
#  ('Italy', 'Martha Silk', 50.49),
#  ('Italy', 'Aaron Mitchell', 50.49),
#  ('Italy', 'Ellie Sullivan', 50.49),
#  ('Italy', 'João Fernandes', 50.49),
#  ('Italy', 'Madalena Sampaio', 50.49),
#  ('Italy', 'Hannah Schneider', 50.49),
#  ('Italy', 'Fynn Zimmermann', 50.49),
#  ('Italy', 'Niklas Schröder', 50.49),
#  ('Italy', 'Camille Bernard', 50.49),
#  ('Italy', 'Dominique Lefebvre', 50.49),
#  ('Italy', 'Marc Dubois', 50.49),
#  ('Italy', 'Wyatt Girard', 50.49),
#  ('Italy', 'Isabelle Mercier', 50.49),
#  ('Italy', 'Terhi Hämäläinen', 50.49),
#  ('Italy', 'Ladislav Kovács', 50.49),
#  ('Italy', "Hugh O'Reilly", 50.49),
#  ('Italy', 'Lucas Mancini', 50.49),
#  ('Italy', 'Johannes Van der Berg', 50.49),
#  ('Italy', 'Stanisław Wójcik', 50.49),
#  ('Italy', 'Enrique Muñoz', 50.49),
#  ('Italy', 'Joakim Johansson', 50.49),
#  ('Italy', 'Emma Jones', 50.49),
#  ('Italy', 'Phil Hughes', 50.49),
#  ('Italy', 'Steve Murray', 50.49),
#  ('Italy', 'Mark Taylor', 50.49),
#  ('Italy', 'Diego Gutiérrez', 50.49),
#  ('Italy', 'Luis Rojas', 50.49),
#  ('Italy', 'Manoj Pareek', 50.49),
#  ('Italy', 'Puja Srivastava', 50.49),
#  ('Netherlands', 'Luís Gonçalves', 65.34),
#  ('Netherlands', 'Leonie Köhler', 65.34),
#  ('Netherlands', 'François Tremblay', 65.34),
#  ('Netherlands', 'Bjørn Hansen', 65.34),
#  ('Netherlands', 'František Wichterlová', 65.34),
#  ('Netherlands', 'Helena Holý', 65.34),
#  ('Netherlands', 'Astrid Gruber', 65.34),
#  ('Netherlands', 'Daan Peeters', 65.34),
#  ('Netherlands', 'Kara Nielsen', 65.34),
#  ('Netherlands', 'Eduardo Martins', 65.34),
#  ('Netherlands', 'Alexandre Rocha', 65.34),
#  ('Netherlands', 'Roberto Almeida', 65.34),
#  ('Netherlands', 'Fernanda Ramos', 65.34),
#  ('Netherlands', 'Mark Philips', 65.34),
#  ('Netherlands', 'Jennifer Peterson', 65.34),
#  ('Netherlands', 'Frank Harris', 65.34),
#  ('Netherlands', 'Jack Smith', 65.34),
#  ('Netherlands', 'Michelle Brooks', 65.34),
#  ('Netherlands', 'Tim Goyer', 65.34),
#  ('Netherlands', 'Dan Miller', 65.34),
#  ('Netherlands', 'Kathy Chase', 65.34),
#  ('Netherlands', 'Heather Leacock', 65.34),
#  ('Netherlands', 'John Gordon', 65.34),
#  ('Netherlands', 'Frank Ralston', 65.34),
#  ('Netherlands', 'Victor Stevens', 65.34),
#  ('Netherlands', 'Richard Cunningham', 65.34),
#  ('Netherlands', 'Patrick Gray', 65.34),
#  ('Netherlands', 'Julia Barnett', 65.34),
#  ('Netherlands', 'Robert Brown', 65.34),
#  ('Netherlands', 'Edward Francis', 65.34),
#  ('Netherlands', 'Martha Silk', 65.34),
#  ('Netherlands', 'Aaron Mitchell', 65.34),
#  ('Netherlands', 'Ellie Sullivan', 65.34),
#  ('Netherlands', 'João Fernandes', 65.34),
#  ('Netherlands', 'Madalena Sampaio', 65.34),
#  ('Netherlands', 'Hannah Schneider', 65.34),
#  ('Netherlands', 'Fynn Zimmermann', 65.34),
#  ('Netherlands', 'Niklas Schröder', 65.34),
#  ('Netherlands', 'Camille Bernard', 65.34),
#  ('Netherlands', 'Dominique Lefebvre', 65.34),
#  ('Netherlands', 'Marc Dubois', 65.34),
#  ('Netherlands', 'Wyatt Girard', 65.34),
#  ('Netherlands', 'Isabelle Mercier', 65.34),
#  ('Netherlands', 'Terhi Hämäläinen', 65.34),
#  ('Netherlands', 'Ladislav Kovács', 65.34),
#  ('Netherlands', "Hugh O'Reilly", 65.34),
#  ('Netherlands', 'Lucas Mancini', 65.34),
#  ('Netherlands', 'Johannes Van der Berg', 65.34),
#  ('Netherlands', 'Stanisław Wójcik', 65.34),
#  ('Netherlands', 'Enrique Muñoz', 65.34),
#  ('Netherlands', 'Joakim Johansson', 65.34),
#  ('Netherlands', 'Emma Jones', 65.34),
#  ('Netherlands', 'Phil Hughes', 65.34),
#  ('Netherlands', 'Steve Murray', 65.34),
#  ('Netherlands', 'Mark Taylor', 65.34),
#  ('Netherlands', 'Diego Gutiérrez', 65.34),
#  ...]

# %%
# Return each genre, with number of tracks sold in USA by price and percentages

# %%
# %%sql
# WITH
#     americans AS
#         (
#             SELECT * FROM customer WHERE country = "USA"
#         ),
#     tracks_in_usa AS
#         (
#             SELECT
#                 track.name
#             FROM track
#             INNER JOIN invoice_line
#                 ON invoice_line.track_id = track.track_id
#             INNER JOIN invoice
#                 ON invoice_line.invoice_id = invoice.invoice_id
#         )
#
# SELECT * FROM tracks_in_usa;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Right Next Door to Hell',),
#  ("Dust N' Bones",),
#  ('Live and Let Die',),
#  ("Don't Cry (Original)",),
#  ('Perfect Crime',),
#  ("You Ain't the First",),
#  ('Bad Obsession',),
#  ('Back off Bitch',),
#  ("Double Talkin' Jive",),
#  ('November Rain',),
#  ('The Garden',),
#  ('Garden of Eden',),
#  ("Don't Damn Me",),
#  ('Bad Apples',),
#  ('Dead Horse',),
#  ('Coma',),
#  ('Help Yourself',),
#  ('Good Riddance (Time Of Your Life)',),
#  ('Blinded By Rainbows',),
#  ('Gallows Pole',),
#  ('Toda Menina Baiana',),
#  ('Pretty Persuasion',),
#  ('Keep It To Myself (Aka Keep It To Yourself)',),
#  ('Talk About Love',),
#  ('Tim Tim Por Tim Tim',),
#  ("Can't Stand Losing You",),
#  ('Black Hole Sun',),
#  ('I Looked At You',),
#  ('Lamentations of Jeremiah, First Set \\ Incipit Lamentatio',),
#  ('Violent Pornography',),
#  ('War Pigs',),
#  ("Let's Get Rocked",),
#  ('Attitude',),
#  ('Dealer',),
#  ("You're What's Happening (In The World Today)",),
#  ('Spoonman',),
#  ('Intro',),
#  ('School',),
#  ('Drain You',),
#  ('Aneurysm',),
#  ('Smells Like Teen Spirit',),
#  ('Been A Son',),
#  ('Lithium',),
#  ('Sliver',),
#  ('Spank Thru',),
#  ('Scentless Apprentice',),
#  ('Heart-Shaped Box',),
#  ('Milk It',),
#  ('Negative Creep',),
#  ('Polly',),
#  ('Breed',),
#  ("Tourette's",),
#  ('Blew',),
#  ('Fly Me To The Moon',),
#  ('Amazing',),
#  ('Amy Amy Amy (Outro)',),
#  ('Das Lied Von Der Erde, Von Der Jugend',),
#  ('Doce De Carnaval (Candy All)',),
#  ('Molina',),
#  ('Drain You',),
#  ('Two Hearts Beat As One',),
#  ('When Love & Hate Collide',),
#  ('Tommy Gun',),
#  ('To Tame A Land',),
#  ('Light My Fire',),
#  ('Right Through You',),
#  ('Time',),
#  ('Hands All Over',),
#  ('Sad But True',),
#  ('Cérebro Eletrônico',),
#  ('Just Another Story',),
#  ('When I Look At The World',),
#  ('Smooth',),
#  ('Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold',),
#  ('Somebody To Love',),
#  ('Victim Of Change (Live)',),
#  ('Prenda Minha',),
#  ("You Know I'm No Good",),
#  ('For Once In My Life',),
#  ('Murders In The Rue Morgue',),
#  ('No More Tears',),
#  ('Nothing Left to Say But Goodbye',),
#  ('Too Fast For Love',),
#  ('Hell',),
#  ('Stone Crazy',),
#  ('Message in a Bottle (new classic rock mix)',),
#  ('The Zoo',),
#  ('English Civil War',),
#  ('Release',),
#  ('Jingo',),
#  ('Alabama Song',),
#  ("Why Can't This Be Love",),
#  ('St. Jimmy',),
#  ('Around The World',),
#  ('Fat Bottomed Girls',),
#  ('My Funny Valentine (Live)',),
#  ('I Got You (I Feel Good)',),
#  ('SCRIABIN: Prelude in B Major, Op. 11, No. 11',),
#  ('Journey To Arnhemland',),
#  ('I Heard It Through The Grapevine',),
#  ('Message in a Bottle (new classic rock mix)',),
#  ('I am the Highway',),
#  ('Where The River Goes',),
#  ('Banho De Lua',),
#  ('Superstition',),
#  ('Are You Experienced?',),
#  ('Stormbringer',),
#  ('War Pigs',),
#  ('Nothingman',),
#  ('Acelerou',),
#  ('Wherever I May Roam',),
#  ('Dog Eat Dog',),
#  ('Magamalabares',),
#  ('Love Is a Losing Game',),
#  ('Exploder',),
#  ('Love In An Elevator',),
#  ("Hell Ain't A Bad Place To Be",),
#  ('I Like Dirt',),
#  ('Black Dog',),
#  ('Wild Side',),
#  ('Where The River Goes',),
#  ('Put You Down',),
#  ('We Are The Champions',),
#  ("I Can't Remember",),
#  ('Lost in Hollywood',),
#  ('Unemployable',),
#  ('Bleed Together',),
#  ('I Got You (I Feel Good)',),
#  ('See You',),
#  ('The Deeper The Love',),
#  ('Going To California',),
#  ('Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold',),
#  ('Boris The Spider',),
#  ('The Worm',),
#  ('Get Off Of My Cloud',),
#  ('I Wish It Would Rain',),
#  ('Love Is a Losing Game',),
#  ('Soul Kitchen',),
#  ('Wasting Love',),
#  ('Get On The Snake',),
#  ('Wonderful Tonight',),
#  ("Doesn't Remind Me",),
#  ('War Pigs',),
#  ('Serenity',),
#  ('You Shook Me',),
#  ('Confusion',),
#  ("OAM's Blues",),
#  ('Your Time Is Gonna Come',),
#  ('Tease Me Please Me',),
#  ('Tease Me Please Me',),
#  ('Mr. Moon',),
#  ('Revenga',),
#  ('When You Gonna Learn (Digeridoo)',),
#  ("Love Ain't No Stranger",),
#  ('Get Me Outta Here',),
#  ('Circles',),
#  ('Night Of The Long Knives',),
#  ('Crumbs From Your Table',),
#  ('Question!',),
#  ('What If I Do?',),
#  ('Ando Meio Desligado',),
#  ('For Those About To Rock (We Salute You)',),
#  ('Put The Finger On You',),
#  ("Let's Get It Up",),
#  ('Inject The Venom',),
#  ('Snowballed',),
#  ('Evil Walks',),
#  ('C.O.D.',),
#  ('Breaking The Rules',),
#  ('Night Of The Long Knives',),
#  ('Spellbound',),
#  ('Welcome to the Jungle',),
#  ("It's So Easy",),
#  ('Nightrain',),
#  ('Out Ta Get Me',),
#  ('Mr. Brownstone',),
#  ('Paradise City',),
#  ('My Michelle',),
#  ('Think About You',),
#  ("Sweet Child O' Mine",),
#  ("You're Crazy",),
#  ('Anything Goes',),
#  ('Rocket Queen',),
#  ('Mary Jane',),
#  ('Easy',),
#  ('You Are',),
#  ('Reggae Music',),
#  ('November Rain',),
#  ('Deuces Are Wild',),
#  ('No Sign of Yesterday',),
#  ('Lazy Gun',),
#  ("Mother's Little Helper",),
#  ('Cochise',),
#  ('Das Lied Von Der Erde, Von Der Jugend',),
#  ('Desire',),
#  ('Another Life',),
#  ('Surfing with the Alien',),
#  ('Speak To Me/Breathe',),
#  ('Planet Home',),
#  ('On The Run',),
#  ('Do It For The Kids',),
#  ('Angel',),
#  ("You Know I'm No Good",),
#  ('Paths Of Glory',),
#  ('Up In Arms',),
#  ('Eu Disse A Ela',),
#  ('Confirmed Dead',),
#  ('How Many More Times',),
#  ('Get On Top',),
#  ('Walking Contradiction',),
#  ('San Francisco Bay Blues',),
#  ('Tears Dry On Their Own',),
#  ('The Other Side',),
#  ('Bê-a-Bá',),
#  ('Give Me Novacaine',),
#  ('Fall To Pieces',),
#  ('On A Plain',),
#  ('No Way Back',),
#  ('Anthem',),
#  ('Californication',),
#  ('He Can Only Hold Her',),
#  ("I Can't Explain",),
#  ('Anyway, Anyhow, Anywhere',),
#  ('My Generation',),
#  ('Substitute',),
#  ("I'm A Boy",),
#  ('Boris The Spider',),
#  ('Happy Jack',),
#  ('Pictures Of Lily',),
#  ('I Can See For Miles',),
#  ('Magic Bus',),
#  ('Pinball Wizard',),
#  ('The Seeker',),
#  ("Baba O'Riley",),
#  ("Won't Get Fooled Again (Full Length Version)",),
#  ("Let's See Action",),
#  ('5.15',),
#  ('Join Together',),
#  ('Squeeze Box',),
#  ('Who Are You (Single Edit Version)',),
#  ('You Better You Bet',),
#  ('All I Really Want',),
#  ('You Oughta Know',),
#  ('Perfect',),
#  ('Hand In My Pocket',),
#  ('Right Through You',),
#  ('Forgiven',),
#  ('You Learn',),
#  ('Head Over Feet',),
#  ('Mary Jane',),
#  ('Ironic',),
#  ('Not The Doctor',),
#  ('Wake Up',),
#  ('You Oughta Know (Alternate)',),
#  ('House Of Pain Anthem',),
#  ('Boris The Spider',),
#  ('Dead And Bloated',),
#  ('I Go Wild',),
#  ('My Funny Valentine (Live)',),
#  ('This Is The Place',),
#  ('The Unforgiven',),
#  ('Make Love Like A Man',),
#  ('Put The Finger On You',),
#  ('What Is It About Men',),
#  ('Stairway To Heaven',),
#  ('Zombie Eaters',),
#  ('Money',),
#  ('Evil Woman',),
#  ('51st Anniversary',),
#  ('Every Little Thing She Does is Magic',),
#  ('The Garden',),
#  ('Just Friends',),
#  ('Get Up Offa That Thing',),
#  ('Na Ladeira',),
#  ('Good Golly Miss Molly',),
#  ('Tired Of You',),
#  ('War Pigs',),
#  ('Tease Me Please Me',),
#  ("Double Talkin' Jive",),
#  ('Until We Fall',),
#  ('De Noite Na Cama',),
#  ('Silver And Gold',),
#  ('Sleeping Village',),
#  ('Gimme Some Truth',),
#  ('Cigaro',),
#  ('Domino',),
#  ('Radio Song',),
#  ('Suite for Solo Cello No. 1 in G Major, BWV 1007: I. Prélude',),
#  ('Low Desert',),
#  ('Moby Dick',),
#  ('2112 Overture',),
#  ('The Deeper The Love',),
#  ('Reach Down',),
#  ('Chemical Wedding',),
#  ('Burden In My Hand',),
#  ('Turandot, Act III, Nessun dorma!',),
#  ('I Could Die For You',),
#  ("Don't Stand so Close to Me",),
#  ('Revenga',),
#  ('Dandelion',),
#  ('Houses Of The Holy',),
#  ('Happy Jack',),
#  ('Up Around The Bend',),
#  ('How Many More Times',),
#  ('Love Is a Losing Game',),
#  ('Eclipse',),
#  ('Evil Woman',),
#  ('Me & Mr. Jones',),
#  ('Jesus Christ Pose',),
#  ('Brand New Car',),
#  ('Peace On Earth',),
#  ('(We Are) The Road Crew',),
#  ('War Pigs',),
#  ('Perfect Strangers',),
#  ('I Looked At You',),
#  ("When It's Love",),
#  ('Molina',),
#  ('Night Of The Long Knives',),
#  ('The Best Is Yet To Come',),
#  ('Tombstone Shadow',),
#  ('El Farol',),
#  ('White Room',),
#  ('Evil Woman',),
#  ('Alberta',),
#  ('Cajueiro',),
#  ('Perfect Crime',),
#  ('Sick Again',),
#  ('Dança Da Solidão',),
#  ('The Crystal Ship',),
#  ('Milk It',),
#  ('Where Have All The Good Times Gone?',),
#  ("Hang 'Em High",),
#  ('Cathedral',),
#  ('Secrets',),
#  ('Intruder',),
#  ('(Oh) Pretty Woman',),
#  ('Dancing In The Street',),
#  ('Little Guitars (Intro)',),
#  ('Little Guitars',),
#  ('Big Bad Bill (Is Sweet William Now)',),
#  ('The Full Bug',),
#  ('Happy Trails',),
#  ('The Unnamed Feeling',),
#  ('You Sure Love To Ball',),
#  ("I Can't Explain",),
#  ('The End',),
#  ("Doesn't Remind Me",),
#  ('Changes',),
#  ("Same Ol' Situation",),
#  ('Seek & Destroy',),
#  ('Break on Through',),
#  ('Soul Kitchen',),
#  ('The Crystal Ship',),
#  ('Twentienth Century Fox',),
#  ('Alabama Song',),
#  ('Light My Fire',),
#  ('Back Door Man',),
#  ('I Looked At You',),
#  ('End Of The Night',),
#  ('Take It As It Comes',),
#  ('The End',),
#  ('Shape of Things to Come',),
#  ('Pretty Noose',),
#  ('Crazy Train',),
#  ('Calling Dr. Love',),
#  ('Jaded',),
#  ('Inject The Venom',),
#  ('Blood',),
#  ('Who Wants To Live Forever',),
#  ('November Rain',),
#  ('Sunshine',),
#  ('Question!',),
#  ('Fade To Black',),
#  ('Like A Bird',),
#  ('Perfect Crime',),
#  ('Like A Bird',),
#  ('My Ship',),
#  ('MFC',),
#  ('You Know My Name',),
#  ('Maquinarama',),
#  ('Everything I Need',),
#  ('País Tropical',),
#  ('Rehab',),
#  ('Good Old-Fashioned Lover Boy',),
#  ('Unemployable',),
#  ('Hey Tonight',),
#  ('Higher Ground',),
#  ('Estranged',),
#  ('Moon germs',),
#  ('J.A.R. (Jason Andrew Relva)',),
#  ('Crazy',),
#  ('Time Is On My Side',),
#  ('Heart Of Stone',),
#  ('Play With Fire',),
#  ('Satisfaction',),
#  ('As Tears Go By',),
#  ('Get Off Of My Cloud',),
#  ("Mother's Little Helper",),
#  ('19th Nervous Breakdown',),
#  ('Paint It Black',),
#  ('Under My Thumb',),
#  ('Ruby Tuesday',),
#  ("Let's Spend The Night Together",),
#  ('The Hellion',),
#  ('Meditação',),
#  ('Cure',),
#  ('Wherever I Lay My Hat',),
#  ("Get My Hands On Some Lovin'",),
#  ('No Good Without You',),
#  ("You've Been A Long Time Coming",),
#  ('When I Had Your Love',),
#  ("You're What's Happening (In The World Today)",),
#  ('Loving You Is Sweeter Than Ever',),
#  ("It's A Bitter Pill To Swallow",),
#  ('Seek And You Shall Find',),
#  ("Gonna Keep On Tryin' Till I Win Your Love",),
#  ("Gonna Give Her All The Love I've Got",),
#  ('I Wish It Would Rain',),
#  ('Abraham, Martin And John',),
#  ('Save The Children',),
#  ('You Sure Love To Ball',),
#  ('Ego Tripping Out',),
#  ('Praise',),
#  ('Heavy Love Affair',),
#  ('Electric Eye',),
#  ('Paint It Black',),
#  ('Breed',),
#  ('Canção Noturna',),
#  ('Smoke On The Water',),
#  ('You Shook Me(2)',),
#  ('Crackerman',),
#  ("Let's Spend The Night Together",),
#  ('Warning',),
#  ("Hitchin' A Ride",),
#  ('Bohemian Rhapsody',),
#  ('Another One Bites The Dust',),
#  ('Killer Queen',),
#  ('Fat Bottomed Girls',),
#  ('Bicycle Race',),
#  ("You're My Best Friend",),
#  ("Don't Stop Me Now",),
#  ('Save Me',),
#  ('Crazy Little Thing Called Love',),
#  ('Somebody To Love',),
#  ("Now I'm Here",),
#  ('Good Old-Fashioned Lover Boy',),
#  ('Play The Game',),
#  ('Flash',),
#  ('Seven Seas Of Rhye',),
#  ('We Will Rock You',),
#  ('We Are The Champions',),
#  ('Grace',),
#  ('February Stars',),
#  ('Light My Fire',),
#  ('Get On Top',),
#  ('Get Off Of My Cloud',),
#  ('Edie (Ciao Baby)',),
#  ('Pseudo Silk Kimono',),
#  ('Calling Dr. Love',),
#  ('Le Sacre Du Printemps: I.iv. Spring Rounds',),
#  ('Bad, Bad Leroy Brown',),
#  ('Soul Kitchen',),
#  ('Old School Hollywood',),
#  ("I Can't Explain",),
#  ('Changes',),
#  ('When My Left Eye Jumps',),
#  ('War Pigs',),
#  ('Journey To Arnhemland',),
#  ('One and the Same',),
#  ('Walking Contradiction',),
#  ('Ride The Lightning',),
#  ('Stormbringer',),
#  ('Everlong',),
#  ('The Temples Of Syrinx',),
#  ('November Rain',),
#  ('Damage Case',),
#  ('Mary Jane',),
#  ('War (The Process)',),
#  ('The Saint',),
#  ('Rise',),
#  ('Take The Power',),
#  ('Breathe',),
#  ('Nico',),
#  ('American Gothic',),
#  ('Ashes And Ghosts',),
#  ('Shape The Sky',),
#  ('Speed Of Light',),
#  ('True Believers',),
#  ('My Bridges Burn',),
#  ('Desire',),
#  ('Getaway Car',),
#  ('Memory Motel',),
#  ('Do You Love Me',),
#  ('I Heard Love Is Blind',),
#  ('Poison Eye',),
#  ('Spank Thru',),
#  ('Put The Finger On You',),
#  ('Inject The Venom',),
#  ('All I Really Want',),
#  ('You Oughta Know',),
#  ('Perfect',),
#  ('Hand In My Pocket',),
#  ('Right Through You',),
#  ('Forgiven',),
#  ('You Learn',),
#  ('Head Over Feet',),
#  ('Mary Jane',),
#  ('Ironic',),
#  ('Not The Doctor',),
#  ('Wake Up',),
#  ('You Oughta Know (Alternate)',),
#  ('Give Me Novacaine',),
#  ('Rita Lee',),
#  ('Too Young To Die',),
#  ('Blanco',),
#  ('Arms Around Your Love',),
#  ('Abraham, Martin And John',),
#  ("Goin' Blind",),
#  ('Bite The Bullet',),
#  ('Infeliz Natal',),
#  ('This Velvet Glove',),
#  ('You Are The Everything',),
#  ('Welcome Home (Sanitarium)',),
#  ('Josephina',),
#  ('You Sent Me Flying / Cherry',),
#  ('Anthem',),
#  ("F*Ckin' Up",),
#  ('Slowness',),
#  ('Loosen My Strings',),
#  ('Snowballed',),
#  ('Lilás',),
#  ('Greasy Grass River',),
#  ('Moby Dick',),
#  ('Good Old-Fashioned Lover Boy',),
#  ('I Know Somethin (Bout You)',),
#  ('Love Child',),
#  ("I Guess You're Right",),
#  ('Polly',),
#  ('The Maids Of Cadiz',),
#  ('Before You Accuse Me',),
#  ('Brain Damage',),
#  ('Smells Like Teen Spirit',),
#  ('Cochise',),
#  ('Show Me How to Live',),
#  ('Gasoline',),
#  ('What You Are',),
#  ('Like a Stone',),
#  ('Set It Off',),
#  ('Shadow on the Sun',),
#  ('I am the Highway',),
#  ('Exploder',),
#  ('Hypnotize',),
#  ("Bring'em Back Alive",),
#  ('Light My Way',),
#  ('Getaway Car',),
#  ('The Last Remaining Light',),
#  ('So Fast, So Numb',),
#  ('Bohemian Rhapsody',),
#  ('Another One Bites The Dust',),
#  ('Killer Queen',),
#  ('Fat Bottomed Girls',),
#  ('Bicycle Race',),
#  ("You're My Best Friend",),
#  ("Don't Stop Me Now",),
#  ('Save Me',),
#  ('Crazy Little Thing Called Love',),
#  ('Somebody To Love',),
#  ("Now I'm Here",),
#  ('Good Old-Fashioned Lover Boy',),
#  ('Play The Game',),
#  ('Flash',),
#  ('Seven Seas Of Rhye',),
#  ('We Will Rock You',),
#  ('We Are The Champions',),
#  ('Amazing',),
#  ('Lost in Hollywood',),
#  ("Nobody's Fault But Mine",),
#  ('Around The World',),
#  ('Parallel Universe',),
#  ('Scar Tissue',),
#  ('Otherside',),
#  ('Get On Top',),
#  ('Californication',),
#  ('Easily',),
#  ('Porcelain',),
#  ('Emit Remmus',),
#  ('I Like Dirt',),
#  ('This Velvet Glove',),
#  ('Savior',),
#  ('Purple Stain',),
#  ('Right On Time',),
#  ("Road Trippin'",),
#  ('Lá Vem O Sol (Here Comes The Sun)',),
#  ("Runnin' With The Devil",),
#  ('Whole Lotta Rosie',),
#  ('Remember',),
#  ('Home Sweet Home',),
#  ('The Clairvoyant',),
#  ('Doll',),
#  ('Monkey Wrench',),
#  ('Hey, Johnny Park!',),
#  ('My Poor Brain',),
#  ('Wind Up',),
#  ('Up In Arms',),
#  ('My Hero',),
#  ('See You',),
#  ('Enough Space',),
#  ('February Stars',),
#  ('Everlong',),
#  ('Walking After You',),
#  ('New Way Home',),
#  ('Go Down',),
#  ('Let There Be Rock',),
#  ('Bad Boy Boogie',),
#  ('Problem Child',),
#  ('Overdose',),
#  ('Whole Lotta Rosie',),
#  ('Remote Control',),
#  ('The Lady Is A Tramp',),
#  ('The Other Side',),
#  ('War Pigs',),
#  ('Transylvania',),
#  ('Times of Trouble',),
#  ('Where The River Goes',),
#  ('Re-Align',),
#  ('With Or Without You',),
#  ('Springsville',),
#  ('The Maids Of Cadiz',),
#  ('The Duke',),
#  ('My Ship',),
#  ('Miles Ahead',),
#  ('Blues For Pablo',),
#  ('New Rhumba',),
#  ('The Meaning Of The Blues',),
#  ('Lament',),
#  ("I Don't Wanna Be Kissed (By Anyone But You)",),
#  ('Springsville (Alternate Take)',),
#  ('Blues For Pablo (Alternate Take)',),
#  ('The Meaning Of The Blues/Lament (Alternate Take)',),
#  ("I Don't Wanna Be Kissed (By Anyone But You) (Alternate Take)",),
#  ('Moth',),
#  ('Fear Of The Dark',),
#  ('Rock Of Ages',),
#  ('Gypsy',),
#  ('Soldier Side - Intro',),
#  ('Knockin On Heavens Door',),
#  ("Can't Get This Stuff No More",),
#  ('Loving You Sunday Morning',),
#  ('Duelists',),
#  ('La Villa Strangiato',),
#  ('Walking Into Clarksdale',),
#  ('Hooks In You',),
#  ('Mean Disposition',),
#  ('Bleed The Freak',),
#  ("You Ain't the First",),
#  ('Heart-Shaped Box',),
#  ('You Better You Bet',),
#  ('When Love Comes To Town',),
#  ('Rehab',),
#  ("You Know I'm No Good",),
#  ('Me & Mr. Jones',),
#  ('Just Friends',),
#  ('Back to Black',),
#  ('Love Is a Losing Game',),
#  ('Tears Dry On Their Own',),
#  ('Wake Up Alone',),
#  ('Some Unholy War',),
#  ('He Can Only Hold Her',),
#  ("You Know I'm No Good (feat. Ghostface Killah)",),
#  ('Rehab (Hot Chip Remix)',),
#  ('B.Y.O.B.',),
#  ('Run To The Hills',),
#  ('Magic Bus',),
#  ('Question!',),
#  ('Kickstart My Heart',),
#  ('Orange Crush',),
#  ("D'Yer Mak'er",),
#  ('Pick Myself Up',),
#  ('Lords of Karma',),
#  ('Still Loving You',),
#  ('Complete Control',),
#  ('Dead And Broken',),
#  ('Amanda',),
#  ('Das Lied Von Der Erde, Von Der Jugend',),
#  ('Flip The Switch',),
#  ('Brand New Car',),
#  ('Tear',),
#  ('Scentless Apprentice',),
#  ('English Civil War',),
#  ('I Wish It Would Rain',),
#  ('To Live Is To Die',),
#  ('Soldier Side - Intro',),
#  ('B.Y.O.B.',),
#  ('Revenga',),
#  ('Cigaro',),
#  ('Radio/Video',),
#  ("This Cocaine Makes Me Feel Like I'm On This Song",),
#  ('Violent Pornography',),
#  ('Question!',),
#  ('Sad Statue',),
#  ('Old School Hollywood',),
#  ('Lost in Hollywood',),
#  ('Lord of Light',),
#  ('Do what cha wanna',),
#  ('Hypnotize',),
#  ('Blood Sugar Sex Magik',),
#  ('London Calling',),
#  ('Fire Fire',),
#  ('Remember',),
#  ("Don't Stand so Close to Me",),
#  ('Turandot, Act III, Nessun dorma!',),
#  ("Hitchin' A Ride",),
#  ('Last Caress/Green Hell',),
#  ('Please Please Please',),
#  ('Think',),
#  ('Night Train',),
#  ('Out Of Sight',),
#  ("Papa's Got A Brand New Bag Pt.1",),
#  ('I Got You (I Feel Good)',),
#  ("It's A Man's Man's Man's World",),
#  ('Cold Sweat',),
#  ("Say It Loud, I'm Black And I'm Proud Pt.1",),
#  ('Get Up (I Feel Like Being A) Sex Machine',),
#  ('Hey America',),
#  ('Make It Funky Pt.1',),
#  ("I'm A Greedy Man Pt.1",),
#  ('Get On The Good Foot',),
#  ('Get Up Offa That Thing',),
#  ("It's Too Funky In Here",),
#  ('Living In America',),
#  ("I'm Real",),
#  ('Hot Pants Pt.1',),
#  ('Soul Power (Live)',),
#  ('Hey Joe',),
#  ('Space Trucking',),
#  ('You Sure Love To Ball',),
#  ('Straight Out Of Line',),
#  ('Break on Through',),
#  ('Save Me',),
#  ('Overdose',),
#  ('Homely Girl',),
#  ('Dr. Heckyll & Mr. Jive',),
#  ('My Poor Brain',),
#  ('You Oughta Know (Alternate)',),
#  ('Coma',),
#  ('Invisible Sun',),
#  ('Forty Days (Com DJ Hum)',),
#  ('Symphony No. 3 in E-flat major, Op. 55, "Eroica" - Scherzo: Allegro Vivace',),
#  ('Aloha',),
#  ('Rime of the Ancient Mariner',),
#  ('(White Man) In Hammersmith Palais',),
#  ('Send Me an Angel',),
#  ('Plush',),
#  ('Wrathchild',),
#  ('When I Come Around',),
#  ('Miracle',),
#  ('The Curse',),
#  ('Bleed The Freak',),
#  ('Dude (Looks Like A Lady)',),
#  ('Commotion',),
#  ('Humans Being',),
#  ('Puteiro Em João Pessoa',),
#  ('Dead And Broken',),
#  ('Crystal Ball',),
#  ('What If I Do?',),
#  ('Fantasia On Greensleeves',),
#  ('Bushleager',),
#  ('Cold Gin',),
#  ('I Wish It Would Rain',),
#  ('War Pigs',),
#  ('Sucker Train Blues',),
#  ('Dog Eat Dog',),
#  ('Wicked Garden',),
#  ('Plaster Caster',),
#  ('Scentless Apprentice',),
#  ('Spirit Walker',),
#  ('I Heard It Through The Grapevine',),
#  ('A Kind Of Magic',),
#  ('The Outlaw Torn',),
#  ('Someday My Prince Will Come',),
#  ('Fried Neckbones And Home Fries',),
#  ('The Duke',),
#  ('Back Door Man',),
#  ('Another One Bites The Dust',),
#  ('White Riot',),
#  ('Remote Control',),
#  ('Complete Control',),
#  ('Clash City Rockers',),
#  ('(White Man) In Hammersmith Palais',),
#  ('Tommy Gun',),
#  ('English Civil War',),
#  ('I Fought The Law',),
#  ('London Calling',),
#  ('Train In Vain',),
#  ('Bankrobber',),
#  ('The Call Up',),
#  ('Hitsville UK',),
#  ('The Magnificent Seven',),
#  ('This Is Radio Clash',),
#  ('Know Your Rights',),
#  ('Rock The Casbah',),
#  ('Should I Stay Or Should I Go',),
#  ('Resolve',),
#  ('Violent Pornography',),
#  ('Breed',),
#  ('Take It As It Comes',),
#  ('Pretty Tied Up',),
#  ('51st Anniversary',),
#  ('Muita Bobeira',),
#  ('Wherever I May Roam',),
#  ('Burden In My Hand',),
#  ('We Will Rock You',),
#  ('In My Bed',),
#  ('Fire',),
#  ('Infinite Dreams',),
#  ('The Other Side',),
#  ('Lithium',),
#  ('Radio GA GA',),
#  ("Look What You've Done",),
#  ("Thinking 'Bout Tomorrow",),
#  ('Sanctuary',),
#  ('Piece Of Pie',),
#  ('Us And Them',),
#  ('Lithium',),
#  ('Spread Your Wings',),
#  ('Finding My Way',),
#  ('February Stars',),
#  ('War Pigs',),
#  ('Once',),
#  ('Mama Africa',),
#  ('Love Child',),
#  ('Love Comes',),
#  ('Cabron',),
#  ('Green Disease',),
#  ('Squeeze Box',),
#  ('Be Good Johnny',),
#  ("Can't Stop",),
#  ('22 Acacia Avenue',),
#  ('Balls to the Wall',),
#  ('May This Be Love',),
#  ('Get Right',),
#  ('Darlene',),
#  ('Help Yourself',),
#  ('For Your Babies',),
#  ('The Small Hours',),
#  ("Macy's Day Parade",),
#  ('Shotgun Blues',),
#  ('Lounge Act',),
#  ('Wrote A Song For Everyone',),
#  ('Looks That Kill',),
#  ('Blitzkrieg',),
#  ('Shakes and Ladders',),
#  ('Love In An Elevator',),
#  ('Rock You Like a Hurricane',),
#  ('For Those About To Rock (We Salute You)',),
#  ('Finding My Way',),
#  ('Serenity',),
#  ("Doesn't Remind Me",),
#  ('Sunshine',),
#  ('Changes',),
#  ('Prowler',),
#  ('Happy Jack',),
#  ('Warning',),
#  ('Loves Been Good To Me',),
#  ('Who Can It Be Now?',),
#  ('Sunchild',),
#  ('For Your Babies',),
#  ('(Wish I Could) Hideaway',),
#  ('Commotion',),
#  ('Big City Nights',),
#  ("It's A Hard Life",),
#  ('Dazed and Confused',),
#  ("Can't Stop",),
#  ('Do You Love Me',),
#  ('Tommy Gun',),
#  ('Sad But True',),
#  ('Safe and Sound',),
#  ('Do It For The Kids',),
#  ('Us And Them',),
#  ('Adios nonino',),
#  ("We've Got To Get Together/Jingo",),
#  ("Now's The Time",),
#  ('Give Me Novacaine',),
#  ('Not The Doctor',),
#  ('Foxy Lady',),
#  ('Manic Depression',),
#  ('Red House',),
#  ('Can You See Me',),
#  ('Love Or Confusion',),
#  ("I Don't Live Today",),
#  ('May This Be Love',),
#  ('Fire',),
#  ('Third Stone From The Sun',),
#  ('Remember',),
#  ('Are You Experienced?',),
#  ('Hey Joe',),
#  ('Stone Free',),
#  ('Purple Haze',),
#  ('51st Anniversary',),
#  ('The Wind Cries Mary',),
#  ('Highway Chile',),
#  ('Cristina Nº 2',),
#  ('Midnight',),
#  ("Don't Stand So Close to Me '86",),
#  ('The Worst',),
#  ('Royal Orleans',),
#  ('Migra',),
#  ('Strangers In The Night',),
#  ('All For You',),
#  ('Get Me Outta Here',),
#  ('Atomic Punk',),
#  ('Foxy Lady',),
#  ('Manic Depression',),
#  ('Red House',),
#  ('Can You See Me',),
#  ('Love Or Confusion',),
#  ("I Don't Live Today",),
#  ('May This Be Love',),
#  ('Fire',),
#  ('Third Stone From The Sun',),
#  ('Remember',),
#  ('Are You Experienced?',),
#  ('Hey Joe',),
#  ('Stone Free',),
#  ('Purple Haze',),
#  ('51st Anniversary',),
#  ('The Wind Cries Mary',),
#  ('Highway Chile',),
#  ('A Cor Do Sol',),
#  ('We Will Rock You',),
#  ('The Saint',),
#  ('Colibri',),
#  ('Times of Trouble',),
#  ('Hawkmoon 269',),
#  ('Sister Morphine',),
#  ('Be Quick Or Be Dead',),
#  ('Welcome Home (Sanitarium)',),
#  ('Love Of My Life',),
#  ('I Can See For Miles',),
#  ('A World Without Heroes',),
#  ('Discotheque',),
#  ('My World',),
#  ('Neworld',),
#  ('Eat The Rich',),
#  ('Por Causa De Você',),
#  ('Breakdown',),
#  ("Hell Ain't A Bad Place To Be",),
#  ('Bohemian Rhapsody',),
#  ('Restless and Wild',),
#  ('All My Love',),
#  ('Radio/Video',),
#  ('White Riot',),
#  ('Creeping Death',),
#  ('Animal',),
#  ('Can You See Me',),
#  ('Wasted Reprise',),
#  ('House And The Rising Sun',),
#  ('Say Hello 2 Heaven',),
#  ('Miles Runs The Voodoo Down',),
#  ('Superhuman',),
#  ('Some Heads Are Gonna Roll',),
#  ('Loud Love',),
#  ('Let There Be Rock',),
#  ('Re-Align',),
#  ('Who Are You (Single Edit Version)',),
#  ('Tommy Gun',),
#  ('Pictures Of Lily',),
#  ('Sapato 36',),
#  ('Every Little Thing She Does is Magic',),
#  ('Piece Of Pie',),
#  ('Hit The Lights',),
#  ('You Learn',),
#  ('Perfect',),
#  ('Ruby Tuesday',),
#  ('SCRIABIN: Prelude in B Major, Op. 11, No. 11',),
#  ('Travelling Riverside Blues',),
#  ('Deuces Are Wild',),
#  ('Something In The Way',),
#  ("Janie's Got A Gun",),
#  ('Right Through You',),
#  ('Rock Of Ages',),
#  ('Sunchild',),
#  ('Smells Like Teen Spirit',),
#  ('In Bloom',),
#  ('Come As You Are',),
#  ('Breed',),
#  ('Lithium',),
#  ('Polly',),
#  ('Territorial Pissings',),
#  ('Drain You',),
#  ('Lounge Act',),
#  ('Stay Away',),
#  ('On A Plain',),
#  ('Something In The Way',),
#  ('Year to the Day',),
#  ('Tres Reis',),
#  ('Fall On Me',),
#  ('Longview',),
#  ('Overdrive',),
#  ('Crash Course In Brain Surgery',),
#  ...]

# %%
# Total dollar amount of sales assigned to each sales support agent

# %%
# Write a query that collates data on purchases from different countries.
# Where a country has only one customer, collect them into an "Other" group.
# The results should be sorted by the total sales from highest to lowest, with the "Other" group at the very bottom.
# For each country, include:
# total number of customers
# total value of sales
# average value of sales per customer
# average order value

# $$ ignore the country from the billing address in the invoice table.
